# %% [markdown]
# Loading libraries

# %%
import pandas as pd
import numpy as np, warnings
from pathlib import Path
import os
import sweetviz as sv
from importlib import reload
import matplotlib.pyplot as plt
import seaborn as sns

np.warnings = warnings

# %%
import sys
sys.path.append("..")

# import utility functions
import src.utils as util
reload(util)

import src.load_parquet as load_parquet
reload(load_parquet)

# setup OS agnostic pathnames
ROOT_DIR = Path('..')

# Note: to run main notebook from root directory, use:
# ROOT_DIR = Path('')

# %% [markdown]
# 1. Loading datasets

# %%
path_labevents = ROOT_DIR / 'data' / "LABEVENTS.csv"
path_demographics = ROOT_DIR / 'data' / "demographic_data.csv"
path_pot_labevents = ROOT_DIR / 'data' / "potential_labevents_combined.csv"
path_diagnoses = ROOT_DIR / 'data'/ "DIAGNOSES_ICD.csv"

# %%
df_labevents = pd.read_csv(path_labevents)
df_demographics = pd.read_csv(path_demographics)
df_pot_labevents = pd.read_csv(path_pot_labevents)
df_diagnoses=pd.read_csv(path_diagnoses)

# %%
df_children=df_demographics[(df_demographics.AGE<18)]

# %%
df_children
# Out:
#        ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 6          27          27   134931  2191-11-30 22:16:00  2191-12-03 14:45:00
# 20         41          39   106266  2114-11-29 21:04:00  2114-12-09 15:10:00
# 27        461         358   110872  2168-10-24 23:48:00  2168-10-29 03:23:00
# 34        468         363   196503  2176-03-01 15:26:00  2176-03-03 14:04:00
# 51         49          50   132761  2112-06-23 19:40:00  2112-06-26 10:15:00
# ...       ...         ...      ...                  ...                  ...
# 55692   53991       84227   169949  2168-03-19 15:14:00  2168-03-25 11:29:00
# 56419   58955       99934   176121  2110-02-28 03:47:00  2110-03-06 14:31:00
# 57584   58652       98995   123142  2155-10-05 02:32:00  2155-10-05 12:00:00
# 57950   58142       97339   198692  2114-08-25 19:20:00  2114-08-28 13:00:00
# 58435   58857       99598   151312  2152-10-25 00:20:00  2152-11-07 14:24:00
#
#                  DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION  \
# 6                      NaN        NEWBORN  PHYS REFERRAL/NORMAL DELI
# 20                     NaN        NEWBORN  PHYS REFERRAL/NORMAL DELI
# 27                     NaN        NEWBORN  PHYS REFERRAL/NORMAL DELI
# 34                     NaN        NEWBORN  CLINIC REFERRAL/PREMATURE
# 51                     NaN        NEWBORN  PHYS REFERRAL/NORMAL DELI
# ...                    ...            ...                        ...
# 55692                  NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 56419                  NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 57584  2155-10-05 12:00:00      EMERGENCY       EMERGENCY ROOM ADMIT
# 57950                  NaN      EMERGENCY  CLINIC REFERRAL/PREMATURE
# 58435                  NaN      EMERGENCY       EMERGENCY ROOM ADMIT
#
#              DISCHARGE_LOCATION   INSURANCE  ...            EDREGTIME  \
# 6                          HOME     Private  ...                  NaN
# 20                         HOME     Private  ...                  NaN
# 27                         HOME     Private  ...                  NaN
# 34                         HOME  Government  ...                  NaN
# 51                         HOME     Private  ...                  NaN
# ...                         ...         ...  ...                  ...
# 55692  REHAB/DISTINCT PART HOSP     Private  ...  2168-03-19 10:42:00
# 56419          HOME HEALTH CARE     Private  ...                  NaN
# 57584              DEAD/EXPIRED     Private  ...  2155-10-04 23:56:00
# 57950                      HOME     Private  ...  2114-08-25 17:53:00
# 58435                      HOME     Private  ...  2152-10-25 00:02:00
#
#                  EDOUTTIME                                         DIAGNOSIS  \
# 6                      NaN                                           NEWBORN
# 20                     NaN                                           NEWBORN
# 27                     NaN                                           NEWBORN
# 34                     NaN                                           NEWBORN
# 51                     NaN                                           NEWBORN
# ...                    ...                                               ...
# 55692  2168-03-19 16:17:00                                   BLADDER RUPTURE
# 56419                  NaN                                    PELVIC ABSCESS
# 57584  2155-10-05 04:04:00                                INTRACRANIAL BLEED
# 57950  2114-08-25 19:20:00                                 EPIDURAL HEMATOMA
# 58435  2152-10-25 00:47:00  STATUS POST MOTOR VEHICLE ACCIDENT WITH INJURIES
#
#       HOSPITAL_EXPIRE_FLAG HAS_CHARTEVENTS_DATA GENDER         DOB  \
# 6                        0                    1      F  2191-11-30
# 20                       0                    1      F  2114-11-29
# 27                       0                    1      F  2168-10-24
# 34                       0                    1      F  2176-03-01
# 51                       0                    1      M  2112-06-23
# ...                    ...                  ...    ...         ...
# 55692                    0                    1      F  2151-03-11
# 56419                    0                    1      M  2092-03-18
# 57584                    1                    1      M  2138-12-23
# 57950                    0                    1      M  2097-01-08
# 58435                    0                    1      M  2135-01-01
#
#        EXPIRE_FLAG  AGE IS_SEPSIS
# 6                0    0         0
# 20               0    0         0
# 27               0    0         0
# 34               0    0         0
# 51               0    0         0
# ...            ...  ...       ...
# 55692            0   17         0
# 56419            0   17         0
# 57584            1   16         0
# 57950            0   17         0
# 58435            0   17         0
#
# [8210 rows x 24 columns]

# %%
child_hadmid = df_children['HADM_ID'].tolist()

# %%
len(child_hadmid)
# Out:
# 8210

# %%
len(df_demographics)
# Out:
# 58976

# %% [markdown]
# 2. Labevents data processing

# %%
#Filtering rows with abnormal Flag
df_labevents = df_labevents[df_labevents['FLAG'] == 'abnormal']

# %%
#Removing rows with missing HADM_ID
df_labevents=df_labevents.dropna(subset=['HADM_ID'])

# %%
#Removing HADM_IDs of children
df_labevents = df_labevents[~df_labevents['HADM_ID'].isin(child_hadmid)]

# %%
#Taking only following columns
df_labevents=df_labevents[['SUBJECT_ID', 'HADM_ID', 'ITEMID']]

# %%
#Removing duplicated rows
df_labevent2=df_labevents[['HADM_ID', 'ITEMID']].drop_duplicates()

# %%
#df_labevent2 has all hadmids with and without sepsis
df_labevent2
# Out:
#            HADM_ID  ITEMID
# 162       145834.0   50893
# 163       145834.0   50902
# 166       145834.0   50912
# 169       145834.0   50970
# 170       145834.0   50971
# ...            ...     ...
# 27853955  107499.0   50998
# 27853979  120151.0   51200
# 27853982  120151.0   51244
# 27853986  120151.0   51254
# 27853987  120151.0   51256
#
# [1355119 rows x 2 columns]

# %% [markdown]
# ### Counting abnormal ITEMIDs with and without sepsis

# %%
#Counting ITEMIDs of all admission
itemid_counts = df_labevent2['ITEMID'].value_counts()

# %%
itemid_counts_df = itemid_counts.reset_index()
itemid_counts_df.columns = ['ITEMID', 'Abnormal_Count']

# %%
itemid_counts_df
# Out:
#      ITEMID  Abnormal_Count
# 0     51279           48216
# 1     50931           48199
# 2     51221           47818
# 3     51222           47649
# 4     51301           38975
# ..      ...             ...
# 285   50816               1
# 286   50913               1
# 287   50802               1
# 288   51113               1
# 289   51437               1
#
# [290 rows x 2 columns]

# %%
#Downloading all itemid count
#itemid_counts_df.to_csv('itemid_allcounts_labevent.csv', index=False)

# %% [markdown]
# ### Counting abnormal ITEMIDs with sepsis patients

# %% [markdown]
# Taking HADM_IDs with newborn sepsis

# %%
#Filtering HADM_IDs with newborn sepsis ICD9COD
nb_sepsis = df_diagnoses[df_diagnoses['ICD9_CODE'] == '77181'][['HADM_ID', 'ICD9_CODE']]

# %%
nb_sepsis
# Out:
#         HADM_ID ICD9_CODE
# 497      142807     77181
# 508      160481     77181
# 2755     154943     77181
# 3804     194246     77181
# 3825     137370     77181
# ...         ...       ...
# 361443   123012     77181
# 363625   163974     77181
# 371487   150568     77181
# 385979   173392     77181
# 392809   161808     77181
#
# [225 rows x 2 columns]

# %%
nb_hadmid = nb_sepsis['HADM_ID'].tolist()

# %% [markdown]
# Counting ITEMIDs with sepsis patient

# %%
#Taking only HADM_ID with sepsis and age >=18
df_withsepsis = df_demographics[(df_demographics['IS_SEPSIS'] == 1) & (df_demographics.AGE >=18)]

# %%
#Taking only HADM_ID and IS_SEPSIS columns
df_withsepsis=df_withsepsis[['HADM_ID', 'AGE','IS_SEPSIS']]

# %%
df_withsepsis
# Out:
#        HADM_ID  AGE  IS_SEPSIS
# 19      185910   75          1
# 23      145674   63          1
# 24      122609   63          1
# 37      134462   52          1
# 63      189535   55          1
# ...        ...  ...        ...
# 58945   186754   84          1
# 58950   168288   69          1
# 58953   153703   69          1
# 58969   141860   80          1
# 58972   105447   88          1
#
# [5176 rows x 3 columns]

# %%
#Taking HADM_IDs with abnormal ITEM_ID
sepsis_df = pd.merge(df_withsepsis, df_labevent2, on='HADM_ID', how='inner')

# %%
#Removing duplicated rows
sepsis_df=sepsis_df[['HADM_ID','ITEMID']].drop_duplicates()

# %%
sepsis_df
# Out:
#         HADM_ID  ITEMID
# 0        185910   50893
# 1        185910   51221
# 2        185910   51222
# 3        185910   51265
# 4        185910   51274
# ...         ...     ...
# 209646   105447   50893
# 209647   105447   50910
# 209648   105447   50960
# 209649   105447   50970
# 209650   105447   51275
#
# [209651 rows x 2 columns]

# %%
#Counting ITEMIDs with sepsis
itemid_counts_sepsis = sepsis_df['ITEMID'].value_counts()

# %%
itemid_counts_sepsis = itemid_counts_sepsis.reset_index()
itemid_counts_sepsis.columns = ['ITEMID', 'Sepsis_abnormal']

# %%
itemid_counts_sepsis
# Out:
#      ITEMID  Sepsis_abnormal
# 0     51222             5114
# 1     51279             5109
# 2     50931             5108
# 3     51221             5094
# 4     50893             4868
# ..      ...              ...
# 265   51224                1
# 266   51210                1
# 267   50894                1
# 268   51459                1
# 269   51435                1
#
# [270 rows x 2 columns]

# %% [markdown]
# ### Adding Counts to the potential labevents file

# %%
#potential labevents file
df_pot_labevents
# Out:
#     ITEMID                                LABEL    FLUID ref1 ref2 chatgpt  \
# 0    50802                          BASE EXCESS    BLOOD  yes   no      no
# 1    50803  CALCULATED BICARBONATE, WHOLE BLOOD    BLOOD  yes   no     yes
# 2    50806                CHLORIDE, WHOLE BLOOD    BLOOD  yes   no      no
# 3    50808                         FREE CALCIUM    BLOOD  yes  yes      no
# 4    50809                              GLUCOSE    BLOOD   no  yes      no
# ..     ...                                  ...      ...  ...  ...     ...
# 79   50804                 CALCULATED TOTAL CO2    BLOOD   no   no     yes
# 80   50910                 CREATINE KINASE (CK)    BLOOD   no   no      no
# 81   51249                                 MCHC    BLOOD   no   no      no
# 82   51516                                  WBC    URINE   no   no     yes
# 83   51116                          LYMPHOCYTES  ASCITES   no   no      no
#
#    neo4j
# 0     no
# 1     no
# 2     no
# 3     no
# 4    yes
# ..   ...
# 79   yes
# 80   yes
# 81   yes
# 82   yes
# 83    no
#
# [84 rows x 7 columns]

# %%
#Adding all abnormal counts to potential labevents 
df_final1 = pd.merge(df_pot_labevents, itemid_counts_df[['ITEMID', 'Abnormal_Count']], on='ITEMID', how='left')

# %%
df_final1
# Out:
#     ITEMID                                LABEL    FLUID ref1 ref2 chatgpt  \
# 0    50802                          BASE EXCESS    BLOOD  yes   no      no
# 1    50803  CALCULATED BICARBONATE, WHOLE BLOOD    BLOOD  yes   no     yes
# 2    50806                CHLORIDE, WHOLE BLOOD    BLOOD  yes   no      no
# 3    50808                         FREE CALCIUM    BLOOD  yes  yes      no
# 4    50809                              GLUCOSE    BLOOD   no  yes      no
# ..     ...                                  ...      ...  ...  ...     ...
# 79   50804                 CALCULATED TOTAL CO2    BLOOD   no   no     yes
# 80   50910                 CREATINE KINASE (CK)    BLOOD   no   no      no
# 81   51249                                 MCHC    BLOOD   no   no      no
# 82   51516                                  WBC    URINE   no   no     yes
# 83   51116                          LYMPHOCYTES  ASCITES   no   no      no
#
#    neo4j  Abnormal_Count
# 0     no             1.0
# 1     no          2318.0
# 2     no          7271.0
# 3     no         22384.0
# 4    yes         24322.0
# ..   ...             ...
# 79   yes         17489.0
# 80   yes         16940.0
# 81   yes         28638.0
# 82   yes         11374.0
# 83    no          1071.0
#
# [84 rows x 8 columns]

# %%
# Adding all sepsis counts  
df_final2 = pd.merge(df_final1, itemid_counts_sepsis, on='ITEMID', how='left')

# %%
df_final2
# Out:
#     ITEMID                                LABEL    FLUID ref1 ref2 chatgpt  \
# 0    50802                          BASE EXCESS    BLOOD  yes   no      no
# 1    50803  CALCULATED BICARBONATE, WHOLE BLOOD    BLOOD  yes   no     yes
# 2    50806                CHLORIDE, WHOLE BLOOD    BLOOD  yes   no      no
# 3    50808                         FREE CALCIUM    BLOOD  yes  yes      no
# 4    50809                              GLUCOSE    BLOOD   no  yes      no
# ..     ...                                  ...      ...  ...  ...     ...
# 79   50804                 CALCULATED TOTAL CO2    BLOOD   no   no     yes
# 80   50910                 CREATINE KINASE (CK)    BLOOD   no   no      no
# 81   51249                                 MCHC    BLOOD   no   no      no
# 82   51516                                  WBC    URINE   no   no     yes
# 83   51116                          LYMPHOCYTES  ASCITES   no   no      no
#
#    neo4j  Abnormal_Count  Sepsis_abnormal
# 0     no             1.0              NaN
# 1     no          2318.0            392.0
# 2     no          7271.0            940.0
# 3     no         22384.0           2724.0
# 4    yes         24322.0           2296.0
# ..   ...             ...              ...
# 79   yes         17489.0           3252.0
# 80   yes         16940.0           2542.0
# 81   yes         28638.0           3067.0
# 82   yes         11374.0           2318.0
# 83    no          1071.0            348.0
#
# [84 rows x 9 columns]

# %%
#Downloading final dataframe with all abnormal count and sepsis abnormal count
#df_final2.to_csv('labevents_features.csv', index=False)

# %% [markdown]
# ### Sorting ITEM_IDs based on 3 proportions

# %%
path_features = ROOT_DIR / 'data' / "features_comparison_draft.csv"
df_features = pd.read_csv(path_features)

# %%
df_features
# Out:
#         #                      LABEL    FLUID ref1 ref2 chatgpt neo4j  \
# 0   51279            RED BLOOD CELLS    BLOOD   no   no      no   yes
# 1   50931                    GLUCOSE    BLOOD   no  yes      no   yes
# 2   51221                 HEMATOCRIT    BLOOD  yes   no      no   yes
# 3   51222                 HEMOGLOBIN    BLOOD  yes   no     yes   yes
# 4   51301         WHITE BLOOD CELLS     BLOOD   no   no     yes   yes
# ..    ...                        ...      ...  ...  ...     ...   ...
# 80  51106           URINE CREATININE    URINE  yes  yes     yes    no
# 81  51133  ABSOLUTE LYMPHOCYTE COUNT    BLOOD   no  yes      no    no
# 82  51253             MONOCYTE COUNT    BLOOD   no  yes      no    no
# 83  51480                 HEMATOCRIT    URINE  yes   no      no    no
# 84  51116                LYMPHOCYTES  ASCITES   no   no      no    no
#
#     Abnormal_Count  Sepsis_abnormal  Sepsis_proportion  Admission_proportion  \
# 0          48216.0           5109.0               0.11                  0.95
# 1          48199.0           5108.0               0.11                  0.95
# 2          47818.0           5094.0               0.11                  0.94
# 3          47649.0           5114.0               0.11                  0.94
# 4          38975.0           4824.0               0.12                  0.77
# ..             ...              ...                ...                   ...
# 80             NaN              NaN               0.00                  0.00
# 81             NaN              NaN               0.00                  0.00
# 82             NaN              NaN               0.00                  0.00
# 83             NaN              NaN               0.00                  0.00
# 84          1071.0            348.0               0.32                  0.02
#
#     Sepsis_admission_proportion
# 0                          0.99
# 1                          0.99
# 2                          0.98
# 3                          0.99
# 4                          0.93
# ..                          ...
# 80                         0.00
# 81                         0.00
# 82                         0.00
# 83                         0.00
# 84                         0.07
#
# [85 rows x 12 columns]

# %% [markdown]
# Sorting based on 3 proportions

# %%
# Create a composite score for each row
df_features['composite_score'] = df_features['Sepsis_proportion'] + df_features['Admission_proportion'] + df_features['Sepsis_admission_proportion']

# Sort the dataframe by the composite score in descending order
df_features = df_features.sort_values(by='composite_score', ascending=False)

# Drop the composite score column if you no longer need it
df_features = df_features.drop(columns=['composite_score'])

# %%
df_features
# Out:
#         #                   LABEL             FLUID ref1 ref2 chatgpt neo4j  \
# 0   51279         RED BLOOD CELLS             BLOOD   no   no      no   yes
# 1   50931                 GLUCOSE             BLOOD   no  yes      no   yes
# 3   51222              HEMOGLOBIN             BLOOD  yes   no     yes   yes
# 2   51221              HEMATOCRIT             BLOOD  yes   no      no   yes
# 4   51301      WHITE BLOOD CELLS              BLOOD   no   no     yes   yes
# ..    ...                     ...               ...  ...  ...     ...   ...
# 66  50833               POTASSIUM  OTHER BODY FLUID  yes   no      no    no
# 65  50830        PCO2, BODY FLUID  OTHER BODY FLUID  yes   no      no    no
# 64  50817       OXYGEN SATURATION             BLOOD  yes   no      no    no
# 62  50802             BASE EXCESS             BLOOD  yes   no      no    no
# 63  50810  HEMATOCRIT, CALCULATED             BLOOD  yes   no      no    no
#
#     Abnormal_Count  Sepsis_abnormal  Sepsis_proportion  Admission_proportion  \
# 0          48216.0           5109.0               0.11                  0.95
# 1          48199.0           5108.0               0.11                  0.95
# 3          47649.0           5114.0               0.11                  0.94
# 2          47818.0           5094.0               0.11                  0.94
# 4          38975.0           4824.0               0.12                  0.77
# ..             ...              ...                ...                   ...
# 66             NaN              NaN               0.00                  0.00
# 65             NaN              NaN               0.00                  0.00
# 64             NaN              NaN               0.00                  0.00
# 62             1.0              NaN               0.00                  0.00
# 63             NaN              NaN               0.00                  0.00
#
#     Sepsis_admission_proportion
# 0                          0.99
# 1                          0.99
# 3                          0.99
# 2                          0.98
# 4                          0.93
# ..                          ...
# 66                         0.00
# 65                         0.00
# 64                         0.00
# 62                         0.00
# 63                         0.00
#
# [85 rows x 12 columns]

# %%
#Downloading sorted data
df_features.to_csv('labevents_comparison_sorted.csv', index=False)
