# %%
import pandas as pd
import numpy as np, warnings
from pathlib import Path
import os
import sys
# import sweetviz as sv
from importlib import reload
import matplotlib.pyplot as plt

np.warnings = warnings

ROOT_DIR = Path('../..')
sys.path.append(os.path.abspath(os.path.join('../src')))
sys.path.append(os.path.abspath(os.path.join('..')))
# import DataLoader as DataLoader
# reload(DataLoader)

# dataLoader = DataLoader.DataLoader(ROOT_DIR)

import src.model_evaluation as me
reload(me)
# Out:
# <module 'src.model_evaluation' from '/home/labadmin/work/data-science-capstone-project/Kha Huynh/src/model_evaluation.py'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# evaluation metrics
from tensorflow.keras.utils import to_categorical
from keras.utils import to_categorical

import tensorflow as tf
# Out:
# 2023-10-21 23:50:52.315479: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-10-21 23:50:52.316584: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-21 23:50:52.341051: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-21 23:50:52.341559: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-21 23:50:52.807947: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Data Preparation - Train val test split

# %%
# t0_df = pd.read_csv(df_final)
path_df = ROOT_DIR / 'data/Model input data/t4_nan.csv'
df_data = pd.read_csv(path_df)# t0_df

admission = df_data[['SUBJECT_ID', 'HADM_ID', 'IS_SEPSIS']].drop_duplicates(["SUBJECT_ID", "HADM_ID"])

def df_split(X, Y, test_size):
    x_train, x_test, y_train, y_test = train_test_split(
        X,  # dropping the target column for X values
        Y,
        test_size=test_size,  # this means 20% test set
        stratify=Y,  # stratify by the target variable
        random_state=42  # to ensure reproducibility
        )
    return x_train, x_test, y_train, y_test

def create_data_df(data_df):
    x_train_df = df_data.merge(data_df[['SUBJECT_ID', 'HADM_ID']])
    x_train_df['count'] = x_train_df.groupby(['SUBJECT_ID', 'HADM_ID'])['HADM_ID'].transform('count')
    x_train_count = x_train_df.drop_duplicates(['SUBJECT_ID', 'HADM_ID'])['count']
    y_train_df = x_train_df.drop_duplicates(['SUBJECT_ID', 'HADM_ID'])['IS_SEPSIS']
    return x_train_df, x_train_count, y_train_df

x_train_df, x_test_df, y_train_df, _ = df_split(admission.drop('IS_SEPSIS', axis=1),  # dropping the target column for X values
                                                admission['IS_SEPSIS'],
                                                test_size=0.2,
                                                )

x_train_df, x_val_df, _, _ = df_split(x_train_df,  # dropping the target column for X values
                                        y_train_df,
                                        test_size=0.15,
                                        )

x_train_df, x_train_count, y_train_df = create_data_df(x_train_df)
x_test_df, x_test_count, y_test_df = create_data_df(x_test_df)
x_val_df, x_val_count, y_val_df = create_data_df(x_val_df)

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='median', missing_values=np.nan)

train_gendernum = x_train_df.GENDER_NUM.values #take out the column doesn't need to scale
test_gendernum = x_test_df.GENDER_NUM.values
val_gendernum = x_val_df.GENDER_NUM.values

# impute X
x_train = imputer.fit_transform(x_train_df.drop(["SUBJECT_ID", "HADM_ID", 'IS_SEPSIS', 'CHARTTIME', 'count', 'GENDER_NUM'], axis=1))
x_test = imputer.transform(x_test_df.drop(["SUBJECT_ID", "HADM_ID", 'IS_SEPSIS', 'CHARTTIME', 'count', 'GENDER_NUM'], axis=1))
x_val = imputer.transform(x_val_df.drop(["SUBJECT_ID", "HADM_ID", 'IS_SEPSIS', 'CHARTTIME', 'count', 'GENDER_NUM'], axis=1))

# %%
# Feature scaling - Standardisation
scaler = StandardScaler()

x_train = scaler.fit_transform(x_train) #scale X
x_test = scaler.transform(x_test)
x_val = scaler.transform(x_val)

x_train = np.column_stack((x_train, train_gendernum)) #merge the columns doesn't need to scale back to X
x_test = np.column_stack((x_test, test_gendernum))
x_val = np.column_stack((x_val, val_gendernum))

# %%
def ts_to_secs(X, X_count, Y):
    secs_data = tf.RaggedTensor.from_row_lengths(X, X_count)
    mask = tf.math.is_finite(secs_data.values)
    mask = tf.RaggedTensor.from_row_lengths(mask, X_count)

    # act_secs_labels = Y.values
    # act_secs_labels = np.array(act_secs_labels)
    act_secs_labels = to_categorical(Y)
    return secs_data, act_secs_labels

# %%
def data_preparation():
  train_data, act_train = ts_to_secs(x_train, x_train_count, y_train_df)
  test_data, act_test = ts_to_secs(x_test, x_test_count, y_test_df)
  val_data, act_val = ts_to_secs(x_val, x_val_count, y_val_df)

  # Here we add an extra dimension to the datasets just to be ready for using with Convolution2D
  print("[INFO] -- Shape of Training Sections:")
  print(train_data.bounding_shape())
  print("[INFO] -- Shape of Test Sections:")
  print(test_data.bounding_shape())
  print("[INFO] -- Shape of Validation Sections:")
  print(val_data.bounding_shape())

  return train_data, act_train, test_data, act_test, val_data, act_val

# %%
x_train, y_train, x_test, y_test, x_val, y_val = data_preparation()
# Out:
# [INFO] -- Shape of Training Sections:
# tf.Tensor([31426    13    43], shape=(3,), dtype=int64)
# [INFO] -- Shape of Test Sections:
# tf.Tensor([9244   13   43], shape=(3,), dtype=int64)
# [INFO] -- Shape of Validation Sections:
# tf.Tensor([5546   10   43], shape=(3,), dtype=int64)

# %% [markdown]
# # Model Definition

# %%
import model_evaluation as me
reload(me)

me.get_class_weights(y_train_df)

# sample_weights = mask_train
sample_weights = me.compute_sample_weights(y_train[:,1].astype(int))
# sample_weights = compute_sample_weights(y_train.astype(int))

# sample_weights_test = mask_test
sample_weights_test = me.compute_sample_weights(y_test[:,1].astype(int))
# sample_weights_test = compute_sample_weights(y_test.astype(int))

# %%
import keras

METRICS = [
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.AUC(name='auc'),
]

m_hist = []
models = []

# %% [markdown]
# # Simple LSTM

# %%
from keras.optimizers import schedules
from keras.callbacks import LearningRateScheduler
import math

init_lr = 0.001

def scheduler(epoch):
  return init_lr * tf.math.exp(-0.1 * epoch)
lr_scheduler = LearningRateScheduler(scheduler)

# %%
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import LSTM, Input, GRU, Masking
from keras.models import Sequential, Model
from sklearn.model_selection import  train_test_split
import time
import keras
import numpy as np
from keras.models import Sequential

def LSTM_model():
    feat_no = x_train[0][0].shape[0]
    d = 0.25
    model=Sequential()
    model.add(Input(shape=[None, feat_no], dtype=tf.float32, ragged=True))
    model.add(LSTM(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax'))

    return model
model = LSTM_model()
models.append(model)

# %%
def LSTM_model():
    feat_no = x_train[0][0].shape[0]
    d = 0.25
    model=Sequential()
    model.add(Input(shape=[None, feat_no], dtype=tf.float32, ragged=True))
    model.add(LSTM(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax'))

    return model
model = LSTM_model()
models.append(model)

# %%
def LSTM_model():
    feat_no = x_train[0][0].shape[0]
    d = 0.25
    model=Sequential()
    model.add(Input(shape=[None, feat_no], dtype=tf.float32, ragged=True))
    model.add(LSTM(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax'))

    return model
model = LSTM_model()
models.append(model)

# %%
for i, model in enumerate(models):
  print(f"----------------Start model {i}---------------------")
  
  model.summary()
  model.compile(optimizer=keras.optimizers.Adam(learning_rate=init_lr), loss='binary_crossentropy', metrics = METRICS)

  checkpointer = ModelCheckpoint(filepath = f'models/weights_best_struct_lstm1_{i}.hdf5', save_best_only = True, monitor='val_accuracy', mode='max')
  early_stop = keras.callbacks.EarlyStopping(monitor = 'val_accuracy', mode = 'max', patience=5, restore_best_weights=True)
  callbacks_list = [lr_scheduler, early_stop, checkpointer]
  # callbacks_list = [lr_scheduler, checkpointer]
  m = model.fit(x_train,y_train,
                sample_weight=sample_weights,
                # class_weight=me.get_class_weights(y_train_df),
                epochs=40, batch_size=64, verbose=1,
                validation_data=(x_val, y_val),
                callbacks=callbacks_list)
  m_hist.append(m)
# Out:
# ----------------Start model 0---------------------
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               88064
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 2)                 258
#
# =================================================================
# Total params: 88322 (345.01 KB)
# Trainable params: 88322 (345.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 492/492 [==============================] - 5s 8ms/step - loss: 0.5748 - accuracy: 0.6967 - auc: 0.7539 - val_loss: 0.5845 - val_accuracy: 0.7328 - val_auc: 0.7822 - lr: 0.0010
# Epoch 2/40
#  15/492 [..............................] - ETA: 3s - loss: 0.5362 - accuracy: 0.7458 - auc: 0.7864
# /home/labadmin/work/data-science-capstone-project/.venv/lib/python3.10/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 492/492 [==============================] - 4s 8ms/step - loss: 0.5174 - accuracy: 0.7657 - auc: 0.8202 - val_loss: 0.5350 - val_accuracy: 0.7667 - val_auc: 0.8281 - lr: 9.0484e-04
# Epoch 3/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.5009 - accuracy: 0.7717 - auc: 0.8321 - val_loss: 0.5259 - val_accuracy: 0.7867 - val_auc: 0.8432 - lr: 8.1873e-04
# Epoch 4/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4872 - accuracy: 0.7813 - auc: 0.8432 - val_loss: 0.5170 - val_accuracy: 0.7878 - val_auc: 0.8508 - lr: 7.4082e-04
# Epoch 5/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4768 - accuracy: 0.7843 - auc: 0.8521 - val_loss: 0.5116 - val_accuracy: 0.7880 - val_auc: 0.8469 - lr: 6.7032e-04
# Epoch 6/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4687 - accuracy: 0.7864 - auc: 0.8544 - val_loss: 0.4956 - val_accuracy: 0.7930 - val_auc: 0.8586 - lr: 6.0653e-04
# Epoch 7/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4598 - accuracy: 0.7938 - auc: 0.8630 - val_loss: 0.5290 - val_accuracy: 0.7842 - val_auc: 0.8468 - lr: 5.4881e-04
# Epoch 8/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4486 - accuracy: 0.7978 - auc: 0.8682 - val_loss: 0.4828 - val_accuracy: 0.7921 - val_auc: 0.8561 - lr: 4.9659e-04
# Epoch 9/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4392 - accuracy: 0.8010 - auc: 0.8741 - val_loss: 0.5308 - val_accuracy: 0.7901 - val_auc: 0.8584 - lr: 4.4933e-04
# Epoch 10/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4312 - accuracy: 0.8026 - auc: 0.8781 - val_loss: 0.5058 - val_accuracy: 0.8042 - val_auc: 0.8719 - lr: 4.0657e-04
# Epoch 11/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4229 - accuracy: 0.8110 - auc: 0.8837 - val_loss: 0.4751 - val_accuracy: 0.8020 - val_auc: 0.8675 - lr: 3.6788e-04
# Epoch 12/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4180 - accuracy: 0.8129 - auc: 0.8867 - val_loss: 0.4711 - val_accuracy: 0.8053 - val_auc: 0.8703 - lr: 3.3287e-04
# Epoch 13/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4233 - accuracy: 0.8127 - auc: 0.8873 - val_loss: 0.4718 - val_accuracy: 0.8038 - val_auc: 0.8670 - lr: 3.0119e-04
# Epoch 14/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4075 - accuracy: 0.8189 - auc: 0.8914 - val_loss: 0.4786 - val_accuracy: 0.8060 - val_auc: 0.8686 - lr: 2.7253e-04
# Epoch 15/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4054 - accuracy: 0.8186 - auc: 0.8934 - val_loss: 0.4740 - val_accuracy: 0.8054 - val_auc: 0.8682 - lr: 2.4660e-04
# Epoch 16/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3980 - accuracy: 0.8241 - auc: 0.8963 - val_loss: 0.4738 - val_accuracy: 0.8112 - val_auc: 0.8721 - lr: 2.2313e-04
# Epoch 17/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3962 - accuracy: 0.8277 - auc: 0.8989 - val_loss: 0.4695 - val_accuracy: 0.8148 - val_auc: 0.8770 - lr: 2.0190e-04
# Epoch 18/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3909 - accuracy: 0.8271 - auc: 0.9015 - val_loss: 0.4976 - val_accuracy: 0.8101 - val_auc: 0.8680 - lr: 1.8268e-04
# Epoch 19/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3854 - accuracy: 0.8329 - auc: 0.9041 - val_loss: 0.4906 - val_accuracy: 0.8136 - val_auc: 0.8724 - lr: 1.6530e-04
# Epoch 20/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3841 - accuracy: 0.8326 - auc: 0.9046 - val_loss: 0.4875 - val_accuracy: 0.8152 - val_auc: 0.8756 - lr: 1.4957e-04
# Epoch 21/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3766 - accuracy: 0.8326 - auc: 0.9065 - val_loss: 0.4924 - val_accuracy: 0.8197 - val_auc: 0.8810 - lr: 1.3534e-04
# Epoch 22/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3783 - accuracy: 0.8343 - auc: 0.9071 - val_loss: 0.5104 - val_accuracy: 0.8137 - val_auc: 0.8742 - lr: 1.2246e-04
# Epoch 23/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3744 - accuracy: 0.8379 - auc: 0.9098 - val_loss: 0.5055 - val_accuracy: 0.8150 - val_auc: 0.8741 - lr: 1.1080e-04
# Epoch 24/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3700 - accuracy: 0.8374 - auc: 0.9109 - val_loss: 0.5171 - val_accuracy: 0.8145 - val_auc: 0.8746 - lr: 1.0026e-04
# Epoch 25/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3721 - accuracy: 0.8396 - auc: 0.9114 - val_loss: 0.5273 - val_accuracy: 0.8128 - val_auc: 0.8725 - lr: 9.0718e-05
# Epoch 26/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3669 - accuracy: 0.8390 - auc: 0.9115 - val_loss: 0.5263 - val_accuracy: 0.8197 - val_auc: 0.8784 - lr: 8.2085e-05
# ----------------Start model 1---------------------
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 256)               307200
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 307714 (1.17 MB)
# Trainable params: 307714 (1.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 492/492 [==============================] - 10s 18ms/step - loss: 0.5583 - accuracy: 0.7210 - auc: 0.7866 - val_loss: 0.5422 - val_accuracy: 0.7779 - val_auc: 0.8311 - lr: 0.0010
# Epoch 2/40
# 492/492 [==============================] - 9s 18ms/step - loss: 0.5131 - accuracy: 0.7598 - auc: 0.8214 - val_loss: 0.5417 - val_accuracy: 0.7800 - val_auc: 0.8322 - lr: 9.0484e-04
# Epoch 3/40
# 492/492 [==============================] - 9s 18ms/step - loss: 0.4929 - accuracy: 0.7703 - auc: 0.8360 - val_loss: 0.4708 - val_accuracy: 0.7977 - val_auc: 0.8720 - lr: 8.1873e-04
# Epoch 4/40
# 492/492 [==============================] - 9s 17ms/step - loss: 0.4807 - accuracy: 0.7772 - auc: 0.8497 - val_loss: 0.5285 - val_accuracy: 0.7957 - val_auc: 0.8616 - lr: 7.4082e-04
# Epoch 5/40
# 492/492 [==============================] - 8s 17ms/step - loss: 0.4671 - accuracy: 0.7833 - auc: 0.8549 - val_loss: 0.5642 - val_accuracy: 0.7672 - val_auc: 0.8295 - lr: 6.7032e-04
# Epoch 6/40
# 492/492 [==============================] - 8s 17ms/step - loss: 0.4596 - accuracy: 0.7935 - auc: 0.8630 - val_loss: 0.5324 - val_accuracy: 0.7840 - val_auc: 0.8551 - lr: 6.0653e-04
# Epoch 7/40
# 492/492 [==============================] - 8s 17ms/step - loss: 0.4419 - accuracy: 0.7970 - auc: 0.8711 - val_loss: 0.5524 - val_accuracy: 0.7930 - val_auc: 0.8606 - lr: 5.4881e-04
# Epoch 8/40
# 492/492 [==============================] - 8s 17ms/step - loss: 0.4277 - accuracy: 0.8060 - auc: 0.8805 - val_loss: 0.6088 - val_accuracy: 0.8029 - val_auc: 0.8739 - lr: 4.9659e-04
# Epoch 9/40
# 492/492 [==============================] - 9s 17ms/step - loss: 0.4166 - accuracy: 0.8101 - auc: 0.8854 - val_loss: 0.6053 - val_accuracy: 0.7975 - val_auc: 0.8644 - lr: 4.4933e-04
# Epoch 10/40
# 492/492 [==============================] - 8s 17ms/step - loss: 0.4122 - accuracy: 0.8140 - auc: 0.8891 - val_loss: 0.4619 - val_accuracy: 0.8074 - val_auc: 0.8745 - lr: 4.0657e-04
# Epoch 11/40
# 492/492 [==============================] - 9s 17ms/step - loss: 0.3985 - accuracy: 0.8213 - auc: 0.8970 - val_loss: 0.5259 - val_accuracy: 0.8136 - val_auc: 0.8834 - lr: 3.6788e-04
# Epoch 12/40
# 492/492 [==============================] - 8s 17ms/step - loss: 0.3864 - accuracy: 0.8276 - auc: 0.9033 - val_loss: 0.5690 - val_accuracy: 0.7990 - val_auc: 0.8637 - lr: 3.3287e-04
# Epoch 13/40
# 492/492 [==============================] - 8s 17ms/step - loss: 0.3766 - accuracy: 0.8315 - auc: 0.9063 - val_loss: 0.6021 - val_accuracy: 0.8118 - val_auc: 0.8772 - lr: 3.0119e-04
# Epoch 14/40
# 492/492 [==============================] - 9s 17ms/step - loss: 0.3667 - accuracy: 0.8393 - auc: 0.9118 - val_loss: 0.6065 - val_accuracy: 0.8154 - val_auc: 0.8828 - lr: 2.7253e-04
# Epoch 15/40
# 492/492 [==============================] - 8s 17ms/step - loss: 0.3605 - accuracy: 0.8400 - auc: 0.9140 - val_loss: 0.5679 - val_accuracy: 0.8228 - val_auc: 0.8885 - lr: 2.4660e-04
# Epoch 16/40
# 492/492 [==============================] - 8s 17ms/step - loss: 0.3539 - accuracy: 0.8454 - auc: 0.9191 - val_loss: 0.5778 - val_accuracy: 0.8145 - val_auc: 0.8808 - lr: 2.2313e-04
# Epoch 17/40
# 492/492 [==============================] - 8s 17ms/step - loss: 0.3456 - accuracy: 0.8472 - auc: 0.9205 - val_loss: 0.5421 - val_accuracy: 0.8269 - val_auc: 0.8913 - lr: 2.0190e-04
# Epoch 18/40
# 492/492 [==============================] - 8s 17ms/step - loss: 0.3460 - accuracy: 0.8488 - auc: 0.9225 - val_loss: 0.5935 - val_accuracy: 0.8071 - val_auc: 0.8708 - lr: 1.8268e-04
# Epoch 19/40
# 492/492 [==============================] - 9s 17ms/step - loss: 0.3364 - accuracy: 0.8523 - auc: 0.9242 - val_loss: 0.6108 - val_accuracy: 0.8175 - val_auc: 0.8818 - lr: 1.6530e-04
# Epoch 20/40
# 492/492 [==============================] - 8s 17ms/step - loss: 0.3305 - accuracy: 0.8563 - auc: 0.9285 - val_loss: 0.6350 - val_accuracy: 0.8168 - val_auc: 0.8805 - lr: 1.4957e-04
# Epoch 21/40
# 492/492 [==============================] - 9s 17ms/step - loss: 0.3266 - accuracy: 0.8584 - auc: 0.9296 - val_loss: 0.6126 - val_accuracy: 0.8141 - val_auc: 0.8758 - lr: 1.3534e-04
# Epoch 22/40
# 492/492 [==============================] - 8s 17ms/step - loss: 0.3229 - accuracy: 0.8613 - auc: 0.9327 - val_loss: 0.6521 - val_accuracy: 0.8193 - val_auc: 0.8808 - lr: 1.2246e-04
# ----------------Start model 2---------------------
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 64)                27648
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 27778 (108.51 KB)
# Trainable params: 27778 (108.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 492/492 [==============================] - 3s 5ms/step - loss: 0.5836 - accuracy: 0.6827 - auc: 0.7529 - val_loss: 0.5287 - val_accuracy: 0.7723 - val_auc: 0.8316 - lr: 0.0010
# Epoch 2/40
# 492/492 [==============================] - 2s 5ms/step - loss: 0.5278 - accuracy: 0.7597 - auc: 0.8165 - val_loss: 0.5020 - val_accuracy: 0.7782 - val_auc: 0.8431 - lr: 9.0484e-04
# Epoch 3/40
# 492/492 [==============================] - 2s 5ms/step - loss: 0.5133 - accuracy: 0.7576 - auc: 0.8221 - val_loss: 0.5095 - val_accuracy: 0.7804 - val_auc: 0.8417 - lr: 8.1873e-04
# Epoch 4/40
# 492/492 [==============================] - 2s 5ms/step - loss: 0.4983 - accuracy: 0.7722 - auc: 0.8399 - val_loss: 0.5445 - val_accuracy: 0.7566 - val_auc: 0.8123 - lr: 7.4082e-04
# Epoch 5/40
# 492/492 [==============================] - 2s 5ms/step - loss: 0.4942 - accuracy: 0.7695 - auc: 0.8374 - val_loss: 0.5112 - val_accuracy: 0.7807 - val_auc: 0.8448 - lr: 6.7032e-04
# Epoch 6/40
# 492/492 [==============================] - 2s 5ms/step - loss: 0.4860 - accuracy: 0.7773 - auc: 0.8477 - val_loss: 0.5139 - val_accuracy: 0.7734 - val_auc: 0.8406 - lr: 6.0653e-04
# Epoch 7/40
# 492/492 [==============================] - 2s 5ms/step - loss: 0.4788 - accuracy: 0.7755 - auc: 0.8465 - val_loss: 0.4834 - val_accuracy: 0.7973 - val_auc: 0.8631 - lr: 5.4881e-04
# Epoch 8/40
# 492/492 [==============================] - 2s 5ms/step - loss: 0.4752 - accuracy: 0.7858 - auc: 0.8560 - val_loss: 0.4835 - val_accuracy: 0.7905 - val_auc: 0.8586 - lr: 4.9659e-04
# Epoch 9/40
# 492/492 [==============================] - 2s 5ms/step - loss: 0.4668 - accuracy: 0.7867 - auc: 0.8577 - val_loss: 0.4941 - val_accuracy: 0.7926 - val_auc: 0.8554 - lr: 4.4933e-04
# Epoch 10/40
# 492/492 [==============================] - 2s 5ms/step - loss: 0.4609 - accuracy: 0.7906 - auc: 0.8622 - val_loss: 0.5078 - val_accuracy: 0.7876 - val_auc: 0.8536 - lr: 4.0657e-04
# Epoch 11/40
# 492/492 [==============================] - 2s 5ms/step - loss: 0.4562 - accuracy: 0.7904 - auc: 0.8638 - val_loss: 0.5295 - val_accuracy: 0.7793 - val_auc: 0.8444 - lr: 3.6788e-04
# Epoch 12/40
# 492/492 [==============================] - 2s 5ms/step - loss: 0.4537 - accuracy: 0.7889 - auc: 0.8640 - val_loss: 0.5481 - val_accuracy: 0.7856 - val_auc: 0.8504 - lr: 3.3287e-04

# %%
import matplotlib.pyplot as plt

for i, _ in enumerate(m_hist):
  # Create a figure with two subplots side by side
  fig, (plt1, plt2, plt3) = plt.subplots(1, 3, figsize=(15, 5))

  # plt.plot(m.history['loss'])
  plt1.plot(m_hist[i].history['accuracy'])
  plt1.plot(m_hist[i].history['val_accuracy'])
  plt1.set_title('model accuracy')
  plt1.set_ylabel('accuracy')
  plt1.set_xlabel('epoch')
  plt1.legend(['accuracy', 'val_accuracy'], loc='upper left')

  # plt.plot(m.history['loss'])
  plt2.plot(m_hist[i].history['auc'])
  plt2.plot(m_hist[i].history['val_auc'])
  plt2.set_title('model auc')
  plt2.set_ylabel('auc')
  plt2.set_xlabel('epoch')
  plt2.legend(['auc', 'val_auc'], loc='upper left')

  # plt.plot(m.history['loss'])
  plt3.plot(m_hist[i].history['loss'])
  plt3.plot(m_hist[i].history['val_loss'])
  plt3.set_title('model loss')
  plt3.set_ylabel('loss')
  plt3.set_xlabel('epoch')
  plt3.legend(['loss', 'val_loss'], loc='upper left')

  plt.tight_layout()
  plt.show()

# %%
fig, (plt1, plt2, plt3) = plt.subplots(1, 3, figsize=(15, 5))
plts = [plt1, plt2, plt3]

chart_types = ['val_accuracy', 'val_auc', 'val_loss']

for i, chart_type in enumerate(chart_types):
  k = 0
  plts[i].plot(m_hist[k].history[chart_type])
  plts[i].plot(m_hist[k+1].history[chart_type])
  plts[i].plot(m_hist[k+2].history[chart_type])
  plts[i].legend([f"lstm1 128 val_acc", f"lstm1 256 val_auc", f"lstm1 64 val_loss"], loc="lower right")

# %%
from keras.models import load_model
reload(me)

trained_models = {}
model_names = ['LSTM 128', 'LSTM 256', 'LSTM 64']
for i, m in enumerate(model_names):
  print("Inference:")
  model = load_model(f"models/weights_best_struct_lstm1_{i}.hdf5")
  model.optimizer.lr.numpy()
  trained_models[m] = model

me.plot_combined_roc_curves(trained_models, x_train, y_train, x_test, y_test)
# me.print_results(model, x_train, y_train, x_test, y_test)
# Out:
# Inference:
# Inference:
# Inference:
# 983/983 [==============================] - 3s 3ms/step
# 289/289 [==============================] - 1s 3ms/step
# 983/983 [==============================] - 5s 5ms/step
# 289/289 [==============================] - 1s 4ms/step
# 983/983 [==============================] - 2s 2ms/step
# 289/289 [==============================] - 1s 2ms/step
#       Model  Balanced acc Train  Balanced acc Test  Precision Train  \
# 0  LSTM 128            0.840032           0.737424         0.400743
# 1  LSTM 256            0.852262           0.716999         0.439382
# 2   LSTM 64            0.784856           0.748317         0.316563
#
#    Precision Test  Recall Train  Recall Test  F1 Train   F1 Test
# 0        0.318341      0.829687     0.640201  0.540447  0.425234
# 1        0.318555      0.832643     0.584925  0.575222  0.412473
# 2        0.292295      0.770254     0.701508  0.448712  0.412651
