# %%
import pandas as pd
import numpy as np, warnings
from pathlib import Path
import os
import sys
# import sweetviz as sv
from importlib import reload
import matplotlib.pyplot as plt

np.warnings = warnings

ROOT_DIR = Path('../..')
sys.path.append(os.path.abspath(os.path.join('../src')))
sys.path.append(os.path.abspath(os.path.join('..')))
import src.DataLoader as DataLoader
reload(DataLoader)

dataLoader = DataLoader.DataLoader(ROOT_DIR)

import src.model_evaluation as me
reload(me)
# Out:
# <module 'src.model_evaluation' from '/home/labadmin/work/data-science-capstone-project/Kha Huynh/src/model_evaluation.py'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# evaluation metrics
from tensorflow.keras.utils import to_categorical
from keras.utils import to_categorical

import tensorflow as tf
# Out:
# 2023-10-21 23:53:23.601396: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-10-21 23:53:23.602570: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-21 23:53:23.628630: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-21 23:53:23.628970: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-21 23:53:24.118633: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Data Preparation - Train val test split

# %%
# t0_df = pd.read_csv(df_final)
path_df = ROOT_DIR / 'data/Model input data/t4_nan.csv'
df_data = pd.read_csv(path_df)# t0_df

admission = df_data[['SUBJECT_ID', 'HADM_ID', 'IS_SEPSIS']].drop_duplicates(["SUBJECT_ID", "HADM_ID"])

def df_split(X, Y, test_size):
    x_train, x_test, y_train, y_test = train_test_split(
        X,  # dropping the target column for X values
        Y,
        test_size=test_size,  # this means 20% test set
        stratify=Y,  # stratify by the target variable
        random_state=42  # to ensure reproducibility
        )
    return x_train, x_test, y_train, y_test

def create_data_df(data_df):
    x_train_df = df_data.merge(data_df[['SUBJECT_ID', 'HADM_ID']])
    x_train_df['count'] = x_train_df.groupby(['SUBJECT_ID', 'HADM_ID'])['HADM_ID'].transform('count')
    x_train_count = x_train_df.drop_duplicates(['SUBJECT_ID', 'HADM_ID'])['count']
    y_train_df = x_train_df.drop_duplicates(['SUBJECT_ID', 'HADM_ID'])['IS_SEPSIS']
    return x_train_df, x_train_count, y_train_df

x_train_df, x_test_df, y_train_df, _ = df_split(admission.drop('IS_SEPSIS', axis=1),  # dropping the target column for X values
                                                admission['IS_SEPSIS'],
                                                test_size=0.2,
                                                )

x_train_df, x_val_df, _, _ = df_split(x_train_df,  # dropping the target column for X values
                                        y_train_df,
                                        test_size=0.15,
                                        )

x_train_df, x_train_count, y_train_df = create_data_df(x_train_df)
x_test_df, x_test_count, y_test_df = create_data_df(x_test_df)
x_val_df, x_val_count, y_val_df = create_data_df(x_val_df)

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='median', missing_values=np.nan)

train_gendernum = x_train_df.GENDER_NUM.values #take out the column doesn't need to scale
test_gendernum = x_test_df.GENDER_NUM.values
val_gendernum = x_val_df.GENDER_NUM.values

# impute X
x_train = imputer.fit_transform(x_train_df.drop(["SUBJECT_ID", "HADM_ID", 'IS_SEPSIS', 'CHARTTIME', 'count', 'GENDER_NUM'], axis=1))
x_test = imputer.transform(x_test_df.drop(["SUBJECT_ID", "HADM_ID", 'IS_SEPSIS', 'CHARTTIME', 'count', 'GENDER_NUM'], axis=1))
x_val = imputer.transform(x_val_df.drop(["SUBJECT_ID", "HADM_ID", 'IS_SEPSIS', 'CHARTTIME', 'count', 'GENDER_NUM'], axis=1))

# %%
# Feature scaling - Standardisation
scaler = StandardScaler()

x_train = scaler.fit_transform(x_train) #scale X
x_test = scaler.transform(x_test)
x_val = scaler.transform(x_val)

x_train = np.column_stack((x_train, train_gendernum)) #merge the columns doesn't need to scale back to X
x_test = np.column_stack((x_test, test_gendernum))
x_val = np.column_stack((x_val, val_gendernum))

# %%
def ts_to_secs(X, X_count, Y):
    secs_data = tf.RaggedTensor.from_row_lengths(X, X_count)
    mask = tf.math.is_finite(secs_data.values)
    mask = tf.RaggedTensor.from_row_lengths(mask, X_count)

    # act_secs_labels = Y.values
    # act_secs_labels = np.array(act_secs_labels)
    act_secs_labels = to_categorical(Y)
    return secs_data, act_secs_labels

# %%
def data_preparation():
  train_data, act_train = ts_to_secs(x_train, x_train_count, y_train_df)
  test_data, act_test = ts_to_secs(x_test, x_test_count, y_test_df)
  val_data, act_val = ts_to_secs(x_val, x_val_count, y_val_df)

  # Here we add an extra dimension to the datasets just to be ready for using with Convolution2D
  print("[INFO] -- Shape of Training Sections:")
  print(train_data.bounding_shape())
  print("[INFO] -- Shape of Test Sections:")
  print(test_data.bounding_shape())
  print("[INFO] -- Shape of Validation Sections:")
  print(val_data.bounding_shape())

  return train_data, act_train, test_data, act_test, val_data, act_val

# %%
x_train, y_train, x_test, y_test, x_val, y_val = data_preparation()
# Out:
# [INFO] -- Shape of Training Sections:
# tf.Tensor([31426    13    43], shape=(3,), dtype=int64)
# [INFO] -- Shape of Test Sections:
# tf.Tensor([9244   13   43], shape=(3,), dtype=int64)
# [INFO] -- Shape of Validation Sections:
# tf.Tensor([5546   10   43], shape=(3,), dtype=int64)

# %% [markdown]
# # Model Definition

# %%
import model_evaluation as me
reload(me)

me.get_class_weights(y_train_df)

# sample_weights = mask_train
sample_weights = me.compute_sample_weights(y_train[:,1].astype(int))
# sample_weights = compute_sample_weights(y_train.astype(int))

# sample_weights_test = mask_test
sample_weights_test = me.compute_sample_weights(y_test[:,1].astype(int))
# sample_weights_test = compute_sample_weights(y_test.astype(int))

# %%
import keras

METRICS = [
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.AUC(name='auc'),
]

m_hist = []
models = []

# %% [markdown]
# # Simple LSTM

# %%
from keras.optimizers import schedules
from keras.callbacks import LearningRateScheduler
import math

init_lr = 0.001

def scheduler(epoch):
  return init_lr * tf.math.exp(-0.1 * epoch)
lr_scheduler = LearningRateScheduler(scheduler)

# %%
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import LSTM, Input, GRU, Masking
from keras.models import Sequential, Model
from sklearn.model_selection import  train_test_split
import time
import keras
import numpy as np
from keras.models import Sequential

def LSTM_model():
    feat_no = x_train[0][0].shape[0]
    d = 0.25
    model=Sequential()
    model.add(Input(shape=[None, feat_no], dtype=tf.float32, ragged=True))
    model.add(LSTM(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax'))

    return model
model = LSTM_model()
models.append(model)

# %%
def LSTM_model():
    feat_no = x_train[0][0].shape[0]
    d = 0.25
    model=Sequential()
    model.add(Input(shape=[None, feat_no], dtype=tf.float32, ragged=True))
    model.add(LSTM(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='sigmoid'))

    return model
model = LSTM_model()
models.append(model)

# %%
def GRU_model():
    feat_no = x_train[0][0].shape[0]
    d = 0.25
    model=Sequential()
    model.add(Input(shape=[None, feat_no], dtype=tf.float32, ragged=True))
    model.add(GRU(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax'))

    return model
model = GRU_model()
models.append(model)

# %%
def GRU_model():
    feat_no = x_train[0][0].shape[0]
    d = 0.25
    model=Sequential()
    model.add(Input(shape=[None, feat_no], dtype=tf.float32, ragged=True))
    model.add(GRU(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='sigmoid'))

    return model
model = GRU_model()
models.append(model)

# %%
for i, model in enumerate(models):
  print(f"----------------Start model {i}---------------------")
  
  model.summary()
  model.compile(optimizer=keras.optimizers.Adam(learning_rate=init_lr), loss='binary_crossentropy', metrics = METRICS)

  checkpointer = ModelCheckpoint(filepath = f'models/weights_best_struct_lstmgru_relu_{i}.hdf5', save_best_only = True, monitor='val_accuracy', mode='max')
  early_stop = keras.callbacks.EarlyStopping(monitor = 'val_accuracy', mode = 'max', patience=5, restore_best_weights=True)
  callbacks_list = [lr_scheduler, early_stop, checkpointer]
  # callbacks_list = [lr_scheduler, checkpointer]
  m = model.fit(x_train,y_train,
                sample_weight=sample_weights,
                # class_weight=me.get_class_weights(y_train_df),
                epochs=40, batch_size=64, verbose=1,
                validation_data=(x_val, y_val),
                callbacks=callbacks_list)
  m_hist.append(m)
# Out:
# ----------------Start model 0---------------------
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               88064
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 2)                 258
#
# =================================================================
# Total params: 88322 (345.01 KB)
# Trainable params: 88322 (345.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 492/492 [==============================] - 5s 9ms/step - loss: 0.5716 - accuracy: 0.6875 - auc: 0.7493 - val_loss: 0.5564 - val_accuracy: 0.7625 - val_auc: 0.8071 - lr: 0.0010
# Epoch 2/40
#  14/492 [..............................] - ETA: 3s - loss: 0.5207 - accuracy: 0.7723 - auc: 0.8268
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
# 492/492 [==============================] - 4s 8ms/step - loss: 0.5212 - accuracy: 0.7652 - auc: 0.8201 - val_loss: 0.5236 - val_accuracy: 0.7647 - val_auc: 0.8233 - lr: 9.0484e-04
# Epoch 3/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.5042 - accuracy: 0.7687 - auc: 0.8292 - val_loss: 0.4836 - val_accuracy: 0.8036 - val_auc: 0.8593 - lr: 8.1873e-04
# Epoch 4/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4908 - accuracy: 0.7759 - auc: 0.8408 - val_loss: 0.4811 - val_accuracy: 0.8015 - val_auc: 0.8660 - lr: 7.4082e-04
# Epoch 5/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4781 - accuracy: 0.7808 - auc: 0.8503 - val_loss: 0.5208 - val_accuracy: 0.7825 - val_auc: 0.8446 - lr: 6.7032e-04
# Epoch 6/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4701 - accuracy: 0.7820 - auc: 0.8531 - val_loss: 0.4771 - val_accuracy: 0.8105 - val_auc: 0.8764 - lr: 6.0653e-04
# Epoch 7/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4585 - accuracy: 0.7885 - auc: 0.8608 - val_loss: 0.4688 - val_accuracy: 0.8065 - val_auc: 0.8764 - lr: 5.4881e-04
# Epoch 8/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4514 - accuracy: 0.7955 - auc: 0.8685 - val_loss: 0.4966 - val_accuracy: 0.7968 - val_auc: 0.8661 - lr: 4.9659e-04
# Epoch 9/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4424 - accuracy: 0.7940 - auc: 0.8707 - val_loss: 0.5112 - val_accuracy: 0.7952 - val_auc: 0.8628 - lr: 4.4933e-04
# Epoch 10/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4333 - accuracy: 0.8012 - auc: 0.8766 - val_loss: 0.4940 - val_accuracy: 0.8002 - val_auc: 0.8666 - lr: 4.0657e-04
# Epoch 11/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4241 - accuracy: 0.8057 - auc: 0.8793 - val_loss: 0.5136 - val_accuracy: 0.7973 - val_auc: 0.8635 - lr: 3.6788e-04
# ----------------Start model 1---------------------
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 128)               88064
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 88322 (345.01 KB)
# Trainable params: 88322 (345.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 492/492 [==============================] - 5s 8ms/step - loss: 0.5718 - accuracy: 0.7037 - auc: 0.7666 - val_loss: 0.5233 - val_accuracy: 0.7858 - val_auc: 0.8377 - lr: 0.0010
# Epoch 2/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.5175 - accuracy: 0.7628 - auc: 0.8200 - val_loss: 0.5332 - val_accuracy: 0.7841 - val_auc: 0.8417 - lr: 9.0484e-04
# Epoch 3/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.5006 - accuracy: 0.7732 - auc: 0.8360 - val_loss: 0.5761 - val_accuracy: 0.7616 - val_auc: 0.8169 - lr: 8.1873e-04
# Epoch 4/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4895 - accuracy: 0.7761 - auc: 0.8436 - val_loss: 0.5408 - val_accuracy: 0.7864 - val_auc: 0.8502 - lr: 7.4082e-04
# Epoch 5/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4771 - accuracy: 0.7795 - auc: 0.8495 - val_loss: 0.5419 - val_accuracy: 0.7777 - val_auc: 0.8439 - lr: 6.7032e-04
# Epoch 6/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4658 - accuracy: 0.7846 - auc: 0.8537 - val_loss: 0.5594 - val_accuracy: 0.7862 - val_auc: 0.8523 - lr: 6.0653e-04
# Epoch 7/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4565 - accuracy: 0.7920 - auc: 0.8630 - val_loss: 0.5408 - val_accuracy: 0.8002 - val_auc: 0.8666 - lr: 5.4881e-04
# Epoch 8/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4467 - accuracy: 0.7930 - auc: 0.8672 - val_loss: 0.5750 - val_accuracy: 0.7972 - val_auc: 0.8642 - lr: 4.9659e-04
# Epoch 9/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4392 - accuracy: 0.8007 - auc: 0.8744 - val_loss: 0.5970 - val_accuracy: 0.7933 - val_auc: 0.8593 - lr: 4.4933e-04
# Epoch 10/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4320 - accuracy: 0.8029 - auc: 0.8782 - val_loss: 0.6313 - val_accuracy: 0.7910 - val_auc: 0.8551 - lr: 4.0657e-04
# Epoch 11/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4247 - accuracy: 0.8046 - auc: 0.8817 - val_loss: 0.6359 - val_accuracy: 0.8019 - val_auc: 0.8704 - lr: 3.6788e-04
# Epoch 12/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4186 - accuracy: 0.8098 - auc: 0.8845 - val_loss: 0.6658 - val_accuracy: 0.8105 - val_auc: 0.8797 - lr: 3.3287e-04
# Epoch 13/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4092 - accuracy: 0.8168 - auc: 0.8923 - val_loss: 0.7067 - val_accuracy: 0.8002 - val_auc: 0.8661 - lr: 3.0119e-04
# Epoch 14/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.4050 - accuracy: 0.8158 - auc: 0.8915 - val_loss: 0.6864 - val_accuracy: 0.8053 - val_auc: 0.8732 - lr: 2.7253e-04
# Epoch 15/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3984 - accuracy: 0.8201 - auc: 0.8968 - val_loss: 0.7293 - val_accuracy: 0.8015 - val_auc: 0.8670 - lr: 2.4660e-04
# Epoch 16/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3987 - accuracy: 0.8211 - auc: 0.8969 - val_loss: 0.7509 - val_accuracy: 0.7957 - val_auc: 0.8609 - lr: 2.2313e-04
# Epoch 17/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3912 - accuracy: 0.8254 - auc: 0.9012 - val_loss: 0.7193 - val_accuracy: 0.8125 - val_auc: 0.8783 - lr: 2.0190e-04
# Epoch 18/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3854 - accuracy: 0.8264 - auc: 0.9031 - val_loss: 0.7394 - val_accuracy: 0.8111 - val_auc: 0.8761 - lr: 1.8268e-04
# Epoch 19/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3795 - accuracy: 0.8297 - auc: 0.9074 - val_loss: 0.7952 - val_accuracy: 0.8118 - val_auc: 0.8772 - lr: 1.6530e-04
# Epoch 20/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3784 - accuracy: 0.8297 - auc: 0.9061 - val_loss: 0.8198 - val_accuracy: 0.8091 - val_auc: 0.8747 - lr: 1.4957e-04
# Epoch 21/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3730 - accuracy: 0.8316 - auc: 0.9091 - val_loss: 0.8236 - val_accuracy: 0.8135 - val_auc: 0.8785 - lr: 1.3534e-04
# Epoch 22/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3765 - accuracy: 0.8323 - auc: 0.9074 - val_loss: 0.8368 - val_accuracy: 0.8092 - val_auc: 0.8748 - lr: 1.2246e-04
# Epoch 23/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3712 - accuracy: 0.8366 - auc: 0.9112 - val_loss: 0.8657 - val_accuracy: 0.8113 - val_auc: 0.8753 - lr: 1.1080e-04
# Epoch 24/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3666 - accuracy: 0.8363 - auc: 0.9116 - val_loss: 0.9148 - val_accuracy: 0.8107 - val_auc: 0.8750 - lr: 1.0026e-04
# Epoch 25/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3669 - accuracy: 0.8353 - auc: 0.9128 - val_loss: 0.9223 - val_accuracy: 0.8113 - val_auc: 0.8748 - lr: 9.0718e-05
# Epoch 26/40
# 492/492 [==============================] - 4s 8ms/step - loss: 0.3655 - accuracy: 0.8403 - auc: 0.9137 - val_loss: 0.9437 - val_accuracy: 0.8126 - val_auc: 0.8756 - lr: 8.2085e-05
# ----------------Start model 2---------------------
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 128)               66432
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 66690 (260.51 KB)
# Trainable params: 66690 (260.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 492/492 [==============================] - 5s 8ms/step - loss: 0.5673 - accuracy: 0.7253 - auc: 0.7868 - val_loss: 0.5101 - val_accuracy: 0.7764 - val_auc: 0.8386 - lr: 0.0010
# Epoch 2/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.5151 - accuracy: 0.7682 - auc: 0.8294 - val_loss: 0.5532 - val_accuracy: 0.7395 - val_auc: 0.8011 - lr: 9.0484e-04
# Epoch 3/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.4986 - accuracy: 0.7736 - auc: 0.8378 - val_loss: 0.5007 - val_accuracy: 0.7764 - val_auc: 0.8411 - lr: 8.1873e-04
# Epoch 4/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.4872 - accuracy: 0.7773 - auc: 0.8444 - val_loss: 0.4623 - val_accuracy: 0.8004 - val_auc: 0.8692 - lr: 7.4082e-04
# Epoch 5/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.4775 - accuracy: 0.7817 - auc: 0.8534 - val_loss: 0.4765 - val_accuracy: 0.7889 - val_auc: 0.8553 - lr: 6.7032e-04
# Epoch 6/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.4655 - accuracy: 0.7862 - auc: 0.8590 - val_loss: 0.5044 - val_accuracy: 0.7674 - val_auc: 0.8382 - lr: 6.0653e-04
# Epoch 7/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.4570 - accuracy: 0.7913 - auc: 0.8632 - val_loss: 0.4342 - val_accuracy: 0.8150 - val_auc: 0.8847 - lr: 5.4881e-04
# Epoch 8/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.4489 - accuracy: 0.7960 - auc: 0.8700 - val_loss: 0.4637 - val_accuracy: 0.7935 - val_auc: 0.8665 - lr: 4.9659e-04
# Epoch 9/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.4375 - accuracy: 0.8021 - auc: 0.8770 - val_loss: 0.4755 - val_accuracy: 0.7955 - val_auc: 0.8633 - lr: 4.4933e-04
# Epoch 10/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.4316 - accuracy: 0.8056 - auc: 0.8793 - val_loss: 0.4452 - val_accuracy: 0.8123 - val_auc: 0.8808 - lr: 4.0657e-04
# Epoch 11/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.4227 - accuracy: 0.8092 - auc: 0.8833 - val_loss: 0.4499 - val_accuracy: 0.8172 - val_auc: 0.8836 - lr: 3.6788e-04
# Epoch 12/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.4193 - accuracy: 0.8112 - auc: 0.8871 - val_loss: 0.4667 - val_accuracy: 0.8081 - val_auc: 0.8761 - lr: 3.3287e-04
# Epoch 13/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.4095 - accuracy: 0.8159 - auc: 0.8910 - val_loss: 0.4710 - val_accuracy: 0.8060 - val_auc: 0.8751 - lr: 3.0119e-04
# Epoch 14/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.4049 - accuracy: 0.8183 - auc: 0.8916 - val_loss: 0.4720 - val_accuracy: 0.8154 - val_auc: 0.8834 - lr: 2.7253e-04
# Epoch 15/40
# 492/492 [==============================] - 3s 7ms/step - loss: 0.3992 - accuracy: 0.8211 - auc: 0.8966 - val_loss: 0.4859 - val_accuracy: 0.8116 - val_auc: 0.8773 - lr: 2.4660e-04
# Epoch 16/40
# 492/492 [==============================] - 3s 7ms/step - loss: 0.3939 - accuracy: 0.8235 - auc: 0.8995 - val_loss: 0.5117 - val_accuracy: 0.7999 - val_auc: 0.8665 - lr: 2.2313e-04
# ----------------Start model 3---------------------
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 128)               66432
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 66690 (260.51 KB)
# Trainable params: 66690 (260.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 492/492 [==============================] - 5s 7ms/step - loss: 0.5659 - accuracy: 0.7278 - auc: 0.7891 - val_loss: 0.4879 - val_accuracy: 0.7966 - val_auc: 0.8559 - lr: 0.0010
# Epoch 2/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.5163 - accuracy: 0.7630 - auc: 0.8252 - val_loss: 0.5126 - val_accuracy: 0.7717 - val_auc: 0.8348 - lr: 9.0484e-04
# Epoch 3/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.5036 - accuracy: 0.7644 - auc: 0.8293 - val_loss: 0.4598 - val_accuracy: 0.8050 - val_auc: 0.8719 - lr: 8.1873e-04
# Epoch 4/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.4918 - accuracy: 0.7734 - auc: 0.8428 - val_loss: 0.4904 - val_accuracy: 0.7826 - val_auc: 0.8518 - lr: 7.4082e-04
# Epoch 5/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.4820 - accuracy: 0.7760 - auc: 0.8483 - val_loss: 0.5274 - val_accuracy: 0.7767 - val_auc: 0.8320 - lr: 6.7032e-04
# Epoch 6/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.4697 - accuracy: 0.7862 - auc: 0.8570 - val_loss: 0.4930 - val_accuracy: 0.7866 - val_auc: 0.8516 - lr: 6.0653e-04
# Epoch 7/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.4619 - accuracy: 0.7875 - auc: 0.8607 - val_loss: 0.4690 - val_accuracy: 0.8017 - val_auc: 0.8700 - lr: 5.4881e-04
# Epoch 8/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.4523 - accuracy: 0.7943 - auc: 0.8683 - val_loss: 0.4850 - val_accuracy: 0.7922 - val_auc: 0.8597 - lr: 4.9659e-04

# %%
import matplotlib.pyplot as plt

for i, _ in enumerate(m_hist):
  # Create a figure with two subplots side by side
  fig, (plt1, plt2, plt3) = plt.subplots(1, 3, figsize=(15, 5))

  # plt.plot(m.history['loss'])
  plt1.plot(m_hist[i].history['accuracy'])
  plt1.plot(m_hist[i].history['val_accuracy'])
  plt1.set_title('model accuracy')
  plt1.set_ylabel('accuracy')
  plt1.set_xlabel('epoch')
  plt1.legend(['accuracy', 'val_accuracy'], loc='upper left')

  # plt.plot(m.history['loss'])
  plt2.plot(m_hist[i].history['auc'])
  plt2.plot(m_hist[i].history['val_auc'])
  plt2.set_title('model auc')
  plt2.set_ylabel('auc')
  plt2.set_xlabel('epoch')
  plt2.legend(['auc', 'val_auc'], loc='upper left')

  # plt.plot(m.history['loss'])
  plt3.plot(m_hist[i].history['loss'])
  plt3.plot(m_hist[i].history['val_loss'])
  plt3.set_title('model loss')
  plt3.set_ylabel('loss')
  plt3.set_xlabel('epoch')
  plt3.legend(['loss', 'val_loss'], loc='upper left')

  plt.tight_layout()
  plt.show()

# %%
fig, (plt1, plt2, plt3) = plt.subplots(1, 3, figsize=(15, 5))
plts = [plt1, plt2, plt3]

chart_types = ['val_accuracy', 'val_auc', 'val_loss']

for i, chart_type in enumerate(chart_types):
  k = 0
  plts[i].plot(m_hist[k].history[chart_type])
  plts[i].plot(m_hist[k+1].history[chart_type])
  plts[i].plot(m_hist[k+2].history[chart_type])
  plts[i].plot(m_hist[k+3].history[chart_type])
  plts[i].legend([f"lstm softmax val_acc", f"lstm sigmoid val_auc", f"gru softmax val_loss", f"gru sigmoid {chart_type}"], loc="lower right")

# %%
from keras.models import load_model
reload(me)

trained_models = {}
model_names = ['LSTM softmax', 'LSTM sigmoid', 'GRU softmax', 'GRU sigmoid']
for i, m in enumerate(model_names):
  print("Inference:")
  model = load_model(f"models/weights_best_struct_lstmgru_relu_{i}.hdf5")
  model.optimizer.lr.numpy()
  trained_models[m] = model

me.plot_combined_roc_curves(trained_models, x_train, y_train, x_test, y_test)
# me.print_results(model, x_train, y_train, x_test, y_test)
# Out:
# Inference:
# Inference:
# Inference:
# Inference:
# 983/983 [==============================] - 3s 3ms/step
# 289/289 [==============================] - 1s 3ms/step
# 983/983 [==============================] - 2s 2ms/step
# 289/289 [==============================] - 1s 3ms/step
# 983/983 [==============================] - 3s 3ms/step
# 289/289 [==============================] - 1s 3ms/step
# 983/983 [==============================] - 2s 2ms/step
# 289/289 [==============================] - 1s 2ms/step
#           Model  Balanced acc Train  Balanced acc Test  Precision Train  \
# 0  LSTM softmax            0.791555           0.753874         0.336586
# 1  LSTM sigmoid            0.845087           0.740138         0.393898
# 2   GRU softmax            0.820484           0.742087         0.372977
# 3   GRU sigmoid            0.768282           0.745679         0.313461
#
#    Precision Test  Recall Train  Recall Test  F1 Train   F1 Test
# 0        0.310531      0.764932     0.693467  0.467474  0.428971
# 1        0.312951      0.847428     0.653266  0.537812  0.423177
# 2        0.314121      0.803962     0.657286  0.509558  0.425089
# 3        0.301109      0.729154     0.682412  0.438439  0.417846
