# %%
import pandas as pd
import numpy as np, warnings
from pathlib import Path
import os
import sys
# import sweetviz as sv
from importlib import reload
import matplotlib.pyplot as plt

np.warnings = warnings

ROOT_DIR = Path('..')
sys.path.append(os.path.abspath(os.path.join('../Kha Huynh/Data cleansing')))
sys.path.append(os.path.abspath(os.path.join('..')))
import DataLoader as DataLoader
reload(DataLoader)

dataLoader = DataLoader.DataLoader(ROOT_DIR)

import model_evaluation as me
reload(me)

import src.modelling_pipeline as modelling_pipeline
reload(modelling_pipeline)

mp = modelling_pipeline.ModelPipeline(ROOT_DIR)
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# evaluation metrics
from tensorflow.keras.utils import to_categorical
from keras.utils import to_categorical

import tensorflow as tf

# %% [markdown]
# # Data Preparation - Train val test split

# %%
# t0_df = pd.read_csv(df_final)
path_df = ROOT_DIR / 'data/Model input data/t4_nan.csv'
df_data = pd.read_csv(path_df)# t0_df

admission = df_data[['SUBJECT_ID', 'HADM_ID', 'IS_SEPSIS']].drop_duplicates(["SUBJECT_ID", "HADM_ID"])

def df_split(X, Y, test_size):
    x_train, x_test, y_train, y_test = train_test_split(
        X,  # dropping the target column for X values
        Y,
        test_size=test_size,  # this means 20% test set
        stratify=Y,  # stratify by the target variable
        random_state=42  # to ensure reproducibility
        )
    return x_train, x_test, y_train, y_test

def create_data_df(data_df):
    x_train_df = df_data.merge(data_df[['SUBJECT_ID', 'HADM_ID']])
    x_train_df['count'] = x_train_df.groupby(['SUBJECT_ID', 'HADM_ID'])['HADM_ID'].transform('count')
    x_train_count = x_train_df.drop_duplicates(['SUBJECT_ID', 'HADM_ID'])['count']
    y_train_df = x_train_df.drop_duplicates(['SUBJECT_ID', 'HADM_ID'])['IS_SEPSIS']
    return x_train_df, x_train_count, y_train_df

x_train_df, x_test_df, y_train_df, _ = df_split(admission.drop('IS_SEPSIS', axis=1),  # dropping the target column for X values
                                                admission['IS_SEPSIS'],
                                                test_size=0.2,
                                                )

x_train_df, x_val_df, _, _ = df_split(x_train_df,  # dropping the target column for X values
                                        y_train_df,
                                        test_size=0.15,
                                        )

x_train_df, x_train_count, y_train_df = create_data_df(x_train_df)
x_test_df, x_test_count, y_test_df = create_data_df(x_test_df)
x_val_df, x_val_count, y_val_df = create_data_df(x_val_df)

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='median', missing_values=np.nan)

train_gendernum = x_train_df.GENDER_NUM.values #take out the column doesn't need to scale
test_gendernum = x_test_df.GENDER_NUM.values
val_gendernum = x_val_df.GENDER_NUM.values

# impute X
x_train = imputer.fit_transform(x_train_df.drop(["SUBJECT_ID", "HADM_ID", 'IS_SEPSIS', 'CHARTTIME', 'count', 'GENDER_NUM'], axis=1))
x_test = imputer.transform(x_test_df.drop(["SUBJECT_ID", "HADM_ID", 'IS_SEPSIS', 'CHARTTIME', 'count', 'GENDER_NUM'], axis=1))
x_val = imputer.transform(x_val_df.drop(["SUBJECT_ID", "HADM_ID", 'IS_SEPSIS', 'CHARTTIME', 'count', 'GENDER_NUM'], axis=1))

# %%
# Feature scaling - Standardisation
scaler = StandardScaler()

x_train = scaler.fit_transform(x_train) #scale X
x_test = scaler.transform(x_test)
x_val = scaler.transform(x_val)

x_train = np.column_stack((x_train, train_gendernum)) #merge the columns doesn't need to scale back to X
x_test = np.column_stack((x_test, test_gendernum))
x_val = np.column_stack((x_val, val_gendernum))

# %%
def ts_to_secs(X, X_count, Y):
    secs_data = tf.RaggedTensor.from_row_lengths(X, X_count)
    mask = tf.math.is_finite(secs_data.values)
    mask = tf.RaggedTensor.from_row_lengths(mask, X_count)

    # act_secs_labels = Y.values
    # act_secs_labels = np.array(act_secs_labels)
    act_secs_labels = to_categorical(Y)
    return secs_data, act_secs_labels, mask

# %%
def data_preparation():
  train_data, act_train, mask_train = ts_to_secs(x_train, x_train_count, y_train_df)
  test_data, act_test, mask_test = ts_to_secs(x_test, x_test_count, y_test_df)
  val_data, act_val, mask_val = ts_to_secs(x_val, x_val_count, y_val_df)

  # Here we add an extra dimension to the datasets just to be ready for using with Convolution2D
  print("[INFO] -- Shape of Training Sections:")
  print(train_data.bounding_shape())
  print("[INFO] -- Shape of Test Sections:")
  print(test_data.bounding_shape())
  print("[INFO] -- Shape of Validation Sections:")
  print(val_data.bounding_shape())

  return train_data, act_train, mask_train, test_data, act_test, mask_test, val_data, act_val, mask_val

# %%
x_train, y_train, mask_train, x_test, y_test, mask_test, x_val, y_val, mask_val = data_preparation()
# Out:
# [INFO] -- Shape of Training Sections:
# tf.Tensor([31426    13    43], shape=(3,), dtype=int64)
# [INFO] -- Shape of Test Sections:
# tf.Tensor([9244   13   43], shape=(3,), dtype=int64)
# [INFO] -- Shape of Validation Sections:
# tf.Tensor([5546   10   43], shape=(3,), dtype=int64)

# %% [markdown]
# # Model Definition

# %%
import model_evaluation as me
reload(me)

me.get_class_weights(y_train_df)

# sample_weights = mask_train
sample_weights = me.compute_sample_weights(y_train[:,1].astype(int))
# sample_weights = compute_sample_weights(y_train.astype(int))

# sample_weights_test = mask_test
sample_weights_test = me.compute_sample_weights(y_test[:,1].astype(int))
# sample_weights_test = compute_sample_weights(y_test.astype(int))

# %%
import keras

METRICS = [
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.AUC(name='auc'),
]

m_hist = []
models = []
model_names = []

# %% [markdown]
# # Simple LSTM

# %%
from keras.optimizers import schedules
from keras.callbacks import LearningRateScheduler
import math

init_lr = 0.001

def scheduler(epoch):
  return init_lr * tf.math.exp(-0.1 * epoch)
lr_scheduler = LearningRateScheduler(scheduler)

# %%
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import LSTM, Input, GRU, Bidirectional, Attention
from keras.models import Sequential, Model
from sklearn.model_selection import  train_test_split
import time
import keras
import numpy as np
from keras.models import Sequential

def LSTM_model():
    feat_no = x_train[0][0].shape[0]
    d=0.25
    model=Sequential()
    model.add(Input(shape=[None, feat_no], dtype=tf.float32, ragged=True))
    model.add(Bidirectional(LSTM(128, activation='relu')))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax'))

    return model
model = LSTM_model()
models.append(model)

# %%
def GRU_model():
    feat_no = x_train[0][0].shape[0]
    d=0.25
    model=Sequential()
    model.add(Input(shape=[None, feat_no], dtype=tf.float32, ragged=True))
    model.add(Bidirectional(GRU(128, activation='relu')))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax'))

    return model
model = GRU_model()
models.append(model)

# %%
for i, model in enumerate(models):
  print(f"----------------Start model {i}---------------------")
  
  model.summary()
  model.compile(optimizer=keras.optimizers.Adam(learning_rate=init_lr), loss='binary_crossentropy', metrics = METRICS)

  checkpointer = ModelCheckpoint(filepath = f'weights_best_struct_bi_{i}.hdf5', save_best_only = True, monitor='val_accuracy', mode='max')
  early_stop = keras.callbacks.EarlyStopping(monitor = 'val_accuracy', mode = 'max', patience=5, restore_best_weights=True)
  callbacks_list = [lr_scheduler, early_stop, checkpointer]
  # callbacks_list = [lr_scheduler, checkpointer]
  m = model.fit(x_train,y_train,
                sample_weight=sample_weights,
                # class_weight=me.get_class_weights(y_train_df),
                epochs=40, batch_size=64, verbose=1,
                validation_data=(x_val, y_val),
                callbacks=callbacks_list)
  m_hist.append(m)
# Out:
# ----------------Start model 0---------------------
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirection  (None, 256)               176128
#  al)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 2)                 514
#
# =================================================================
# Total params: 176642 (690.01 KB)
# Trainable params: 176642 (690.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 492/492 [==============================] - 8s 11ms/step - loss: 0.5644 - accuracy: 0.7141 - auc: 0.7717 - val_loss: 0.6166 - val_accuracy: 0.7095 - val_auc: 0.7504 - lr: 0.0010
# Epoch 2/40
#   7/492 [..............................] - ETA: 4s - loss: 0.5433 - accuracy: 0.7143 - auc: 0.7645
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
# 492/492 [==============================] - 5s 10ms/step - loss: 0.5108 - accuracy: 0.7645 - auc: 0.8259 - val_loss: 0.5221 - val_accuracy: 0.7865 - val_auc: 0.8476 - lr: 9.0484e-04
# Epoch 3/40
# 492/492 [==============================] - 6s 12ms/step - loss: 0.4945 - accuracy: 0.7745 - auc: 0.8404 - val_loss: 0.5547 - val_accuracy: 0.7586 - val_auc: 0.8178 - lr: 8.1873e-04
# Epoch 4/40
# 492/492 [==============================] - 7s 14ms/step - loss: 0.4825 - accuracy: 0.7749 - auc: 0.8440 - val_loss: 0.5070 - val_accuracy: 0.8020 - val_auc: 0.8662 - lr: 7.4082e-04
# Epoch 5/40
# 492/492 [==============================] - 7s 15ms/step - loss: 0.4667 - accuracy: 0.7877 - auc: 0.8582 - val_loss: 0.5203 - val_accuracy: 0.7883 - val_auc: 0.8551 - lr: 6.7032e-04
# Epoch 6/40
# 492/492 [==============================] - 8s 16ms/step - loss: 0.4565 - accuracy: 0.7914 - auc: 0.8612 - val_loss: 0.5194 - val_accuracy: 0.7988 - val_auc: 0.8655 - lr: 6.0653e-04
# Epoch 7/40
# 492/492 [==============================] - 7s 15ms/step - loss: 0.4442 - accuracy: 0.7984 - auc: 0.8717 - val_loss: 0.5433 - val_accuracy: 0.7979 - val_auc: 0.8671 - lr: 5.4881e-04
# Epoch 8/40
# 492/492 [==============================] - 7s 15ms/step - loss: 0.4385 - accuracy: 0.8013 - auc: 0.8735 - val_loss: 0.5419 - val_accuracy: 0.8035 - val_auc: 0.8651 - lr: 4.9659e-04
# Epoch 9/40
# 492/492 [==============================] - 7s 14ms/step - loss: 0.4317 - accuracy: 0.8064 - auc: 0.8797 - val_loss: 0.5507 - val_accuracy: 0.7970 - val_auc: 0.8613 - lr: 4.4933e-04
# Epoch 10/40
# 492/492 [==============================] - 7s 14ms/step - loss: 0.4211 - accuracy: 0.8116 - auc: 0.8846 - val_loss: 0.5923 - val_accuracy: 0.8100 - val_auc: 0.8749 - lr: 4.0657e-04
# Epoch 11/40
# 492/492 [==============================] - 7s 15ms/step - loss: 0.4148 - accuracy: 0.8166 - auc: 0.8885 - val_loss: 0.6261 - val_accuracy: 0.8081 - val_auc: 0.8765 - lr: 3.6788e-04
# Epoch 12/40
# 492/492 [==============================] - 7s 14ms/step - loss: 0.4056 - accuracy: 0.8198 - auc: 0.8944 - val_loss: 0.7228 - val_accuracy: 0.8067 - val_auc: 0.8693 - lr: 3.3287e-04
# Epoch 13/40
# 492/492 [==============================] - 7s 14ms/step - loss: 0.3985 - accuracy: 0.8210 - auc: 0.8948 - val_loss: 0.5073 - val_accuracy: 0.8015 - val_auc: 0.8707 - lr: 3.0119e-04
# Epoch 14/40
# 492/492 [==============================] - 7s 15ms/step - loss: 0.3915 - accuracy: 0.8255 - auc: 0.8998 - val_loss: 0.5675 - val_accuracy: 0.8161 - val_auc: 0.8793 - lr: 2.7253e-04
# Epoch 15/40
# 492/492 [==============================] - 7s 14ms/step - loss: 0.3878 - accuracy: 0.8271 - auc: 0.9013 - val_loss: 0.5648 - val_accuracy: 0.8182 - val_auc: 0.8845 - lr: 2.4660e-04
# Epoch 16/40
# 492/492 [==============================] - 7s 14ms/step - loss: 0.3783 - accuracy: 0.8320 - auc: 0.9071 - val_loss: 0.6139 - val_accuracy: 0.8049 - val_auc: 0.8667 - lr: 2.2313e-04
# Epoch 17/40
# 492/492 [==============================] - 7s 14ms/step - loss: 0.3760 - accuracy: 0.8314 - auc: 0.9056 - val_loss: 0.6585 - val_accuracy: 0.8091 - val_auc: 0.8733 - lr: 2.0190e-04
# Epoch 18/40
# 492/492 [==============================] - 7s 15ms/step - loss: 0.3714 - accuracy: 0.8351 - auc: 0.9090 - val_loss: 0.7214 - val_accuracy: 0.8159 - val_auc: 0.8797 - lr: 1.8268e-04
# Epoch 19/40
# 492/492 [==============================] - 7s 14ms/step - loss: 0.3654 - accuracy: 0.8402 - auc: 0.9132 - val_loss: 0.6687 - val_accuracy: 0.8168 - val_auc: 0.8817 - lr: 1.6530e-04
# Epoch 20/40
# 492/492 [==============================] - 8s 15ms/step - loss: 0.3625 - accuracy: 0.8414 - auc: 0.9138 - val_loss: 0.6639 - val_accuracy: 0.8146 - val_auc: 0.8779 - lr: 1.4957e-04
# ----------------Start model 1---------------------
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirecti  (None, 256)               132864
#  onal)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 133378 (521.01 KB)
# Trainable params: 133378 (521.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 492/492 [==============================] - 9s 14ms/step - loss: 0.5623 - accuracy: 0.7281 - auc: 0.7956 - val_loss: 0.5563 - val_accuracy: 0.7477 - val_auc: 0.8038 - lr: 0.0010
# Epoch 2/40
# 492/492 [==============================] - 7s 14ms/step - loss: 0.5085 - accuracy: 0.7637 - auc: 0.8291 - val_loss: 0.4832 - val_accuracy: 0.7860 - val_auc: 0.8531 - lr: 9.0484e-04
# Epoch 3/40
# 492/492 [==============================] - 7s 14ms/step - loss: 0.4956 - accuracy: 0.7736 - auc: 0.8410 - val_loss: 0.4828 - val_accuracy: 0.7901 - val_auc: 0.8549 - lr: 8.1873e-04
# Epoch 4/40
# 492/492 [==============================] - 7s 15ms/step - loss: 0.4805 - accuracy: 0.7801 - auc: 0.8515 - val_loss: 0.4748 - val_accuracy: 0.7899 - val_auc: 0.8586 - lr: 7.4082e-04
# Epoch 5/40
# 492/492 [==============================] - 7s 15ms/step - loss: 0.4699 - accuracy: 0.7853 - auc: 0.8582 - val_loss: 0.4989 - val_accuracy: 0.7816 - val_auc: 0.8468 - lr: 6.7032e-04
# Epoch 6/40
# 492/492 [==============================] - 8s 15ms/step - loss: 0.4581 - accuracy: 0.7886 - auc: 0.8626 - val_loss: 0.4858 - val_accuracy: 0.7894 - val_auc: 0.8549 - lr: 6.0653e-04
# Epoch 7/40
# 492/492 [==============================] - 7s 15ms/step - loss: 0.4467 - accuracy: 0.7959 - auc: 0.8701 - val_loss: 0.4471 - val_accuracy: 0.8078 - val_auc: 0.8787 - lr: 5.4881e-04
# Epoch 8/40
# 492/492 [==============================] - 8s 16ms/step - loss: 0.4381 - accuracy: 0.8028 - auc: 0.8769 - val_loss: 0.4763 - val_accuracy: 0.7896 - val_auc: 0.8627 - lr: 4.9659e-04
# Epoch 9/40
# 492/492 [==============================] - 7s 14ms/step - loss: 0.4257 - accuracy: 0.8054 - auc: 0.8821 - val_loss: 0.4740 - val_accuracy: 0.7923 - val_auc: 0.8665 - lr: 4.4933e-04
# Epoch 10/40
# 492/492 [==============================] - 8s 15ms/step - loss: 0.4143 - accuracy: 0.8131 - auc: 0.8873 - val_loss: 0.4597 - val_accuracy: 0.8054 - val_auc: 0.8780 - lr: 4.0657e-04
# Epoch 11/40
# 492/492 [==============================] - 8s 15ms/step - loss: 0.4092 - accuracy: 0.8158 - auc: 0.8908 - val_loss: 0.4721 - val_accuracy: 0.8063 - val_auc: 0.8778 - lr: 3.6788e-04
# Epoch 12/40
# 492/492 [==============================] - 7s 15ms/step - loss: 0.3968 - accuracy: 0.8223 - auc: 0.8972 - val_loss: 0.4733 - val_accuracy: 0.8148 - val_auc: 0.8836 - lr: 3.3287e-04
# Epoch 13/40
# 492/492 [==============================] - 7s 15ms/step - loss: 0.3892 - accuracy: 0.8300 - auc: 0.9016 - val_loss: 0.4951 - val_accuracy: 0.8074 - val_auc: 0.8750 - lr: 3.0119e-04
# Epoch 14/40
# 492/492 [==============================] - 7s 15ms/step - loss: 0.3823 - accuracy: 0.8299 - auc: 0.9041 - val_loss: 0.5107 - val_accuracy: 0.8000 - val_auc: 0.8673 - lr: 2.7253e-04
# Epoch 15/40
# 492/492 [==============================] - 7s 14ms/step - loss: 0.3777 - accuracy: 0.8277 - auc: 0.9035 - val_loss: 0.4800 - val_accuracy: 0.8155 - val_auc: 0.8851 - lr: 2.4660e-04
# Epoch 16/40
# 492/492 [==============================] - 7s 14ms/step - loss: 0.3703 - accuracy: 0.8354 - auc: 0.9100 - val_loss: 0.5119 - val_accuracy: 0.8130 - val_auc: 0.8836 - lr: 2.2313e-04
# Epoch 17/40
# 492/492 [==============================] - 7s 14ms/step - loss: 0.3643 - accuracy: 0.8380 - auc: 0.9118 - val_loss: 0.5259 - val_accuracy: 0.8091 - val_auc: 0.8780 - lr: 2.0190e-04
# Epoch 18/40
# 492/492 [==============================] - 7s 15ms/step - loss: 0.3586 - accuracy: 0.8423 - auc: 0.9162 - val_loss: 0.5487 - val_accuracy: 0.8054 - val_auc: 0.8742 - lr: 1.8268e-04
# Epoch 19/40
# 492/492 [==============================] - 7s 15ms/step - loss: 0.3527 - accuracy: 0.8412 - auc: 0.9154 - val_loss: 0.5269 - val_accuracy: 0.8190 - val_auc: 0.8892 - lr: 1.6530e-04
# Epoch 20/40
# 492/492 [==============================] - 7s 15ms/step - loss: 0.3504 - accuracy: 0.8468 - auc: 0.9198 - val_loss: 0.5319 - val_accuracy: 0.8168 - val_auc: 0.8814 - lr: 1.4957e-04
# Epoch 21/40
# 492/492 [==============================] - 7s 14ms/step - loss: 0.3485 - accuracy: 0.8495 - auc: 0.9206 - val_loss: 0.5408 - val_accuracy: 0.8154 - val_auc: 0.8843 - lr: 1.3534e-04
# Epoch 22/40
# 492/492 [==============================] - 7s 15ms/step - loss: 0.3443 - accuracy: 0.8489 - auc: 0.9210 - val_loss: 0.5526 - val_accuracy: 0.8190 - val_auc: 0.8853 - lr: 1.2246e-04
# Epoch 23/40
# 492/492 [==============================] - 7s 15ms/step - loss: 0.3408 - accuracy: 0.8511 - auc: 0.9230 - val_loss: 0.5534 - val_accuracy: 0.8238 - val_auc: 0.8909 - lr: 1.1080e-04
# Epoch 24/40
# 492/492 [==============================] - 7s 15ms/step - loss: 0.3351 - accuracy: 0.8536 - auc: 0.9250 - val_loss: 0.5488 - val_accuracy: 0.8220 - val_auc: 0.8898 - lr: 1.0026e-04
# Epoch 25/40
# 492/492 [==============================] - 7s 15ms/step - loss: 0.3337 - accuracy: 0.8575 - auc: 0.9283 - val_loss: 0.5847 - val_accuracy: 0.8109 - val_auc: 0.8757 - lr: 9.0718e-05
# Epoch 26/40
# 492/492 [==============================] - 7s 15ms/step - loss: 0.3334 - accuracy: 0.8541 - auc: 0.9253 - val_loss: 0.5538 - val_accuracy: 0.8228 - val_auc: 0.8900 - lr: 8.2085e-05
# Epoch 27/40
# 492/492 [==============================] - 7s 15ms/step - loss: 0.3290 - accuracy: 0.8582 - auc: 0.9293 - val_loss: 0.5632 - val_accuracy: 0.8201 - val_auc: 0.8845 - lr: 7.4274e-05
# Epoch 28/40
# 492/492 [==============================] - 7s 14ms/step - loss: 0.3268 - accuracy: 0.8560 - auc: 0.9285 - val_loss: 0.5667 - val_accuracy: 0.8222 - val_auc: 0.8875 - lr: 6.7206e-05

# %%
import matplotlib.pyplot as plt

lr_name = ['Step-base', 'Time-base', 'Exponential-base']
for i, _ in enumerate(m_hist):
  # Create a figure with two subplots side by side
  fig, (plt1, plt2, plt3) = plt.subplots(1, 3, figsize=(15, 5))

  # plt.plot(m.history['loss'])
  plt1.plot(m_hist[i].history['accuracy'])
  plt1.plot(m_hist[i].history['val_accuracy'])
  plt1.set_title('model accuracy')
  plt1.set_ylabel('accuracy')
  plt1.set_xlabel('epoch')
  plt1.legend(['accuracy', 'val_accuracy'], loc='upper left')

  # plt.plot(m.history['loss'])
  plt2.plot(m_hist[i].history['auc'])
  plt2.plot(m_hist[i].history['val_auc'])
  plt2.set_title('model auc')
  plt2.set_ylabel('auc')
  plt2.set_xlabel('epoch')
  plt2.legend(['auc', 'val_auc'], loc='upper left')

  # plt.plot(m.history['loss'])
  plt3.plot(m_hist[i].history['loss'])
  plt3.plot(m_hist[i].history['val_loss'])
  plt3.set_title('model loss')
  plt3.set_ylabel('loss')
  plt3.set_xlabel('epoch')
  plt3.legend(['loss', 'val_loss'], loc='upper left')

  plt.tight_layout()
  plt.show()

# %%
fig, (plt1, plt2, plt3) = plt.subplots(1, 3, figsize=(15, 5))
plts = [plt1, plt2, plt3]

chart_types = ['val_accuracy', 'val_auc', 'val_loss']

for i, chart_type in enumerate(chart_types):
  k = 0
  plts[i].plot(m_hist[k].history[chart_type])
  plts[i].plot(m_hist[k+1].history[chart_type])
  plts[i].legend([f"Bi LSTM {chart_type}", f"Bi GRU {chart_type}"], loc="lower right")

# %%
from keras.models import load_model
reload(me)

trained_models = {}
model_names = ['Bi-LSTM', 'Bi-GRU']
for i, m in enumerate(model_names):
  print("Inference:")
  model = load_model(f"weights_best_struct_bi_{i}.hdf5")
  model.optimizer.lr.numpy()
  trained_models[m] = model

me.plot_combined_roc_curves(trained_models, x_train, y_train, x_test, y_test)
# me.print_results(model, x_train, y_train, x_test, y_test)
# Out:
# Inference:
# Inference:
# 983/983 [==============================] - 3s 2ms/step
# 289/289 [==============================] - 1s 2ms/step
# 983/983 [==============================] - 2s 2ms/step
# 289/289 [==============================] - 1s 2ms/step
#      Model  Balanced acc Train  Balanced acc Test  Precision Train  \
# 0  Bi-LSTM            0.838850           0.742971         0.397365
# 1   Bi-GRU            0.863119           0.720630         0.441634
#
#    Precision Test  Recall Train  Recall Test  F1 Train   F1 Test
# 0        0.314477      0.829391     0.659296  0.537305  0.425836
# 1        0.318280      0.856889     0.594975  0.582864  0.414711
