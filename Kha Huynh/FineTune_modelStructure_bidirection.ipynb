# %%
import pandas as pd
import numpy as np, warnings
from pathlib import Path
import os
import sys
# import sweetviz as sv
from importlib import reload
import matplotlib.pyplot as plt

np.warnings = warnings

ROOT_DIR = Path('..')
sys.path.append(os.path.abspath(os.path.join('../Kha Huynh/Data cleansing')))
sys.path.append(os.path.abspath(os.path.join('..')))
import DataLoader as DataLoader
reload(DataLoader)

dataLoader = DataLoader.DataLoader(ROOT_DIR)

import model_evaluation as me
reload(me)

import src.modelling_pipeline as modelling_pipeline
reload(modelling_pipeline)

mp = modelling_pipeline.ModelPipeline(ROOT_DIR)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# evaluation metrics
from tensorflow.keras.utils import to_categorical
from keras.utils import to_categorical

import tensorflow as tf
# Out:
# 2023-10-21 03:42:14.378237: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-10-21 03:42:14.410295: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-21 03:42:14.410317: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-21 03:42:14.410334: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-21 03:42:14.417732: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-21 03:42:15.189228: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Data Preparation - Train val test split

# %%
# t0_df = pd.read_csv(df_final)
path_df = ROOT_DIR / 'data/Model input data/t4_nan.csv'
df_data = pd.read_csv(path_df)# t0_df

admission = df_data[['SUBJECT_ID', 'HADM_ID', 'IS_SEPSIS']].drop_duplicates(["SUBJECT_ID", "HADM_ID"])

def df_split(X, Y, test_size):
    x_train, x_test, y_train, y_test = train_test_split(
        X,  # dropping the target column for X values
        Y,
        test_size=test_size,  # this means 20% test set
        stratify=Y,  # stratify by the target variable
        random_state=42  # to ensure reproducibility
        )
    return x_train, x_test, y_train, y_test

def create_data_df(data_df):
    x_train_df = df_data.merge(data_df[['SUBJECT_ID', 'HADM_ID']])
    x_train_df['count'] = x_train_df.groupby(['SUBJECT_ID', 'HADM_ID'])['HADM_ID'].transform('count')
    x_train_count = x_train_df.drop_duplicates(['SUBJECT_ID', 'HADM_ID'])['count']
    y_train_df = x_train_df.drop_duplicates(['SUBJECT_ID', 'HADM_ID'])['IS_SEPSIS']
    return x_train_df, x_train_count, y_train_df

x_train_df, x_test_df, y_train_df, _ = df_split(admission.drop('IS_SEPSIS', axis=1),  # dropping the target column for X values
                                                admission['IS_SEPSIS'],
                                                test_size=0.2,
                                                )

x_train_df, x_val_df, _, _ = df_split(x_train_df,  # dropping the target column for X values
                                        y_train_df,
                                        test_size=0.15,
                                        )

x_train_df, x_train_count, y_train_df = create_data_df(x_train_df)
x_test_df, x_test_count, y_test_df = create_data_df(x_test_df)
x_val_df, x_val_count, y_val_df = create_data_df(x_val_df)

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='median', missing_values=np.nan)

train_gendernum = x_train_df.GENDER_NUM.values #take out the column doesn't need to scale
test_gendernum = x_test_df.GENDER_NUM.values
val_gendernum = x_val_df.GENDER_NUM.values

# impute X
x_train = imputer.fit_transform(x_train_df.drop(["SUBJECT_ID", "HADM_ID", 'IS_SEPSIS', 'CHARTTIME', 'count', 'GENDER_NUM'], axis=1))
x_test = imputer.transform(x_test_df.drop(["SUBJECT_ID", "HADM_ID", 'IS_SEPSIS', 'CHARTTIME', 'count', 'GENDER_NUM'], axis=1))
x_val = imputer.transform(x_val_df.drop(["SUBJECT_ID", "HADM_ID", 'IS_SEPSIS', 'CHARTTIME', 'count', 'GENDER_NUM'], axis=1))

# %%
# Feature scaling - Standardisation
scaler = StandardScaler()

x_train = scaler.fit_transform(x_train) #scale X
x_test = scaler.transform(x_test)
x_val = scaler.transform(x_val)

x_train = np.column_stack((x_train, train_gendernum)) #merge the columns doesn't need to scale back to X
x_test = np.column_stack((x_test, test_gendernum))
x_val = np.column_stack((x_val, val_gendernum))

# %%
def ts_to_secs(X, X_count, Y):
    secs_data = tf.RaggedTensor.from_row_lengths(X, X_count)
    mask = tf.math.is_finite(secs_data.values)
    mask = tf.RaggedTensor.from_row_lengths(mask, X_count)

    # act_secs_labels = Y.values
    # act_secs_labels = np.array(act_secs_labels)
    act_secs_labels = to_categorical(Y)
    return secs_data, act_secs_labels, mask

# %%
def data_preparation():
  train_data, act_train, mask_train = ts_to_secs(x_train, x_train_count, y_train_df)
  test_data, act_test, mask_test = ts_to_secs(x_test, x_test_count, y_test_df)
  val_data, act_val, mask_val = ts_to_secs(x_val, x_val_count, y_val_df)

  # Here we add an extra dimension to the datasets just to be ready for using with Convolution2D
  print("[INFO] -- Shape of Training Sections:")
  print(train_data.bounding_shape())
  print("[INFO] -- Shape of Test Sections:")
  print(test_data.bounding_shape())
  print("[INFO] -- Shape of Validation Sections:")
  print(val_data.bounding_shape())

  return train_data, act_train, mask_train, test_data, act_test, mask_test, val_data, act_val, mask_val

# %%
x_train, y_train, mask_train, x_test, y_test, mask_test, x_val, y_val, mask_val = data_preparation()
# Out:
# [INFO] -- Shape of Training Sections:
# tf.Tensor([31426    13    43], shape=(3,), dtype=int64)
# [INFO] -- Shape of Test Sections:
# tf.Tensor([9244   13   43], shape=(3,), dtype=int64)
# [INFO] -- Shape of Validation Sections:
# tf.Tensor([5546   10   43], shape=(3,), dtype=int64)

# %% [markdown]
# # Model Definition

# %%
import model_evaluation as me
reload(me)

me.get_class_weights(y_train_df)

# sample_weights = mask_train
sample_weights = me.compute_sample_weights(y_train[:,1].astype(int))
# sample_weights = compute_sample_weights(y_train.astype(int))

# sample_weights_test = mask_test
sample_weights_test = me.compute_sample_weights(y_test[:,1].astype(int))
# sample_weights_test = compute_sample_weights(y_test.astype(int))

# %%
import keras

METRICS = [
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.AUC(name='auc'),
]

m_hist = []
models = []
model_names = []

# %% [markdown]
# # Simple LSTM

# %%
from keras.optimizers import schedules
from keras.callbacks import LearningRateScheduler
import math

init_lr = 0.001

def scheduler(epoch):
  return init_lr * tf.math.exp(-0.1 * epoch)
lr_scheduler = LearningRateScheduler(scheduler)

# %%
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import LSTM, Input, GRU, Bidirectional, Attention
from keras.models import Sequential, Model
from sklearn.model_selection import  train_test_split
import time
import keras
import numpy as np
from keras.models import Sequential

def LSTM_model():
    feat_no = x_train[0][0].shape[0]
    d=0.25
    model=Sequential()
    model.add(Input(shape=[None, feat_no], dtype=tf.float32, ragged=True))
    model.add(Bidirectional(LSTM(128, activation='relu')))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax'))

    return model
model = LSTM_model()
models.append(model)

# %%
def LSTM_model():
    feat_no = x_train[0][0].shape[0]
    d=0.25
    model=Sequential()
    model.add(Input(shape=[None, feat_no], dtype=tf.float32, ragged=True))
    model.add(Bidirectional(LSTM(64, activation='relu')))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='sigmoid'))

    return model
model = LSTM_model()
models.append(model)

# %%
def GRU_model():
    feat_no = x_train[0][0].shape[0]
    d=0.25
    model=Sequential()
    model.add(Input(shape=[None, feat_no], dtype=tf.float32, ragged=True))
    model.add(Bidirectional(GRU(128, activation='relu')))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax'))

    return model
model = GRU_model()
models.append(model)

# %%
def GRU_model():
    feat_no = x_train[0][0].shape[0]
    d=0.25
    model=Sequential()
    model.add(Input(shape=[None, feat_no], dtype=tf.float32, ragged=True))
    model.add(Bidirectional(GRU(64, activation='relu')))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='sigmoid'))

    return model
model = GRU_model()
models.append(model)

# %%
for i, model in enumerate(models):
  print(f"----------------Start model {i}---------------------")
  
  model.summary()
  model.compile(optimizer=keras.optimizers.Adam(learning_rate=init_lr), loss='binary_crossentropy', metrics = METRICS)

  checkpointer = ModelCheckpoint(filepath = f'weights_best_struct_bi_{i}.hdf5', save_best_only = True, monitor='val_accuracy', mode='max')
  early_stop = keras.callbacks.EarlyStopping(monitor = 'val_accuracy', mode = 'max', patience=5, restore_best_weights=True)
  callbacks_list = [lr_scheduler, early_stop, checkpointer]
  # callbacks_list = [lr_scheduler, checkpointer]
  m = model.fit(x_train,y_train,
                sample_weight=sample_weights,
                # class_weight=me.get_class_weights(y_train_df),
                epochs=40, batch_size=64, verbose=1,
                validation_data=(x_val, y_val),
                callbacks=callbacks_list)
  m_hist.append(m)
# Out:
# ----------------Start model 0---------------------
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirection  (None, 256)               176128
#  al)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 2)                 514
#
# =================================================================
# Total params: 176642 (690.01 KB)
# Trainable params: 176642 (690.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 492/492 [==============================] - 7s 11ms/step - loss: 0.5642 - accuracy: 0.6993 - auc: 0.7625 - val_loss: 0.5011 - val_accuracy: 0.7916 - val_auc: 0.8517 - lr: 0.0010
# Epoch 2/40
#  13/492 [..............................] - ETA: 4s - loss: 0.5089 - accuracy: 0.7788 - auc: 0.8332
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
# 492/492 [==============================] - 5s 10ms/step - loss: 0.5129 - accuracy: 0.7674 - auc: 0.8290 - val_loss: 0.5485 - val_accuracy: 0.7407 - val_auc: 0.8036 - lr: 9.0484e-04
# Epoch 3/40
# 492/492 [==============================] - 5s 10ms/step - loss: 0.4960 - accuracy: 0.7692 - auc: 0.8351 - val_loss: 0.5406 - val_accuracy: 0.7672 - val_auc: 0.8266 - lr: 8.1873e-04
# Epoch 4/40
# 492/492 [==============================] - 5s 10ms/step - loss: 0.4817 - accuracy: 0.7754 - auc: 0.8439 - val_loss: 0.4904 - val_accuracy: 0.7853 - val_auc: 0.8489 - lr: 7.4082e-04
# Epoch 5/40
# 492/492 [==============================] - 5s 10ms/step - loss: 0.4710 - accuracy: 0.7873 - auc: 0.8566 - val_loss: 0.5242 - val_accuracy: 0.7818 - val_auc: 0.8485 - lr: 6.7032e-04
# Epoch 6/40
# 492/492 [==============================] - 5s 10ms/step - loss: 0.4590 - accuracy: 0.7903 - auc: 0.8627 - val_loss: 0.5529 - val_accuracy: 0.7679 - val_auc: 0.8307 - lr: 6.0653e-04
# ----------------Start model 1---------------------
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirecti  (None, 128)               55296
#  onal)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 55554 (217.01 KB)
# Trainable params: 55554 (217.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 492/492 [==============================] - 6s 8ms/step - loss: 0.5737 - accuracy: 0.6960 - auc: 0.7599 - val_loss: 0.6132 - val_accuracy: 0.7055 - val_auc: 0.7533 - lr: 0.0010
# Epoch 2/40
# 492/492 [==============================] - 3s 7ms/step - loss: 0.5177 - accuracy: 0.7595 - auc: 0.8194 - val_loss: 0.5440 - val_accuracy: 0.7563 - val_auc: 0.8140 - lr: 9.0484e-04
# Epoch 3/40
# 492/492 [==============================] - 3s 7ms/step - loss: 0.5046 - accuracy: 0.7629 - auc: 0.8294 - val_loss: 0.4755 - val_accuracy: 0.7935 - val_auc: 0.8616 - lr: 8.1873e-04
# Epoch 4/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.4923 - accuracy: 0.7722 - auc: 0.8413 - val_loss: 0.5158 - val_accuracy: 0.7656 - val_auc: 0.8330 - lr: 7.4082e-04
# Epoch 5/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.4828 - accuracy: 0.7777 - auc: 0.8481 - val_loss: 0.4863 - val_accuracy: 0.7871 - val_auc: 0.8552 - lr: 6.7032e-04
# Epoch 6/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.4727 - accuracy: 0.7836 - auc: 0.8542 - val_loss: 0.4752 - val_accuracy: 0.7949 - val_auc: 0.8655 - lr: 6.0653e-04
# Epoch 7/40
# 492/492 [==============================] - 3s 7ms/step - loss: 0.4624 - accuracy: 0.7874 - auc: 0.8597 - val_loss: 0.4758 - val_accuracy: 0.7916 - val_auc: 0.8648 - lr: 5.4881e-04
# Epoch 8/40
# 492/492 [==============================] - 3s 7ms/step - loss: 0.4526 - accuracy: 0.7912 - auc: 0.8652 - val_loss: 0.4929 - val_accuracy: 0.7890 - val_auc: 0.8589 - lr: 4.9659e-04
# Epoch 9/40
# 492/492 [==============================] - 3s 7ms/step - loss: 0.4472 - accuracy: 0.7963 - auc: 0.8709 - val_loss: 0.4896 - val_accuracy: 0.7964 - val_auc: 0.8661 - lr: 4.4933e-04
# Epoch 10/40
# 492/492 [==============================] - 3s 6ms/step - loss: 0.4462 - accuracy: 0.7963 - auc: 0.8693 - val_loss: 0.5006 - val_accuracy: 0.7865 - val_auc: 0.8536 - lr: 4.0657e-04
# Epoch 11/40
# 492/492 [==============================] - 3s 7ms/step - loss: 0.4366 - accuracy: 0.7989 - auc: 0.8744 - val_loss: 0.4734 - val_accuracy: 0.7996 - val_auc: 0.8717 - lr: 3.6788e-04
# Epoch 12/40
# 492/492 [==============================] - 4s 7ms/step - loss: 0.4310 - accuracy: 0.8011 - auc: 0.8773 - val_loss: 0.4803 - val_accuracy: 0.7983 - val_auc: 0.8659 - lr: 3.3287e-04
# Epoch 13/40
# 492/492 [==============================] - 3s 6ms/step - loss: 0.4301 - accuracy: 0.8055 - auc: 0.8805 - val_loss: 0.4844 - val_accuracy: 0.7941 - val_auc: 0.8625 - lr: 3.0119e-04
# Epoch 14/40
# 492/492 [==============================] - 3s 7ms/step - loss: 0.4233 - accuracy: 0.8102 - auc: 0.8846 - val_loss: 0.4988 - val_accuracy: 0.7929 - val_auc: 0.8614 - lr: 2.7253e-04
# Epoch 15/40
# 492/492 [==============================] - 3s 6ms/step - loss: 0.4154 - accuracy: 0.8111 - auc: 0.8886 - val_loss: 0.4943 - val_accuracy: 0.8031 - val_auc: 0.8699 - lr: 2.4660e-04
# Epoch 16/40
# 492/492 [==============================] - 3s 7ms/step - loss: 0.4168 - accuracy: 0.8102 - auc: 0.8871 - val_loss: 0.4848 - val_accuracy: 0.8069 - val_auc: 0.8759 - lr: 2.2313e-04
# Epoch 17/40
# 492/492 [==============================] - 3s 6ms/step - loss: 0.4129 - accuracy: 0.8138 - auc: 0.8894 - val_loss: 0.4981 - val_accuracy: 0.8034 - val_auc: 0.8712 - lr: 2.0190e-04
# Epoch 18/40
# 492/492 [==============================] - 3s 7ms/step - loss: 0.4072 - accuracy: 0.8168 - auc: 0.8936 - val_loss: 0.5066 - val_accuracy: 0.8033 - val_auc: 0.8718 - lr: 1.8268e-04
# Epoch 19/40
# 492/492 [==============================] - 3s 6ms/step - loss: 0.4043 - accuracy: 0.8184 - auc: 0.8949 - val_loss: 0.5132 - val_accuracy: 0.7968 - val_auc: 0.8642 - lr: 1.6530e-04
# Epoch 20/40
# 492/492 [==============================] - 3s 6ms/step - loss: 0.4020 - accuracy: 0.8188 - auc: 0.8951 - val_loss: 0.5199 - val_accuracy: 0.7998 - val_auc: 0.8690 - lr: 1.4957e-04
# Epoch 21/40
# 492/492 [==============================] - 3s 7ms/step - loss: 0.4031 - accuracy: 0.8152 - auc: 0.8933 - val_loss: 0.4959 - val_accuracy: 0.8135 - val_auc: 0.8813 - lr: 1.3534e-04
# Epoch 22/40
# 492/492 [==============================] - 3s 7ms/step - loss: 0.4000 - accuracy: 0.8179 - auc: 0.8966 - val_loss: 0.5000 - val_accuracy: 0.8117 - val_auc: 0.8807 - lr: 1.2246e-04
# Epoch 23/40
# 492/492 [==============================] - 3s 6ms/step - loss: 0.3973 - accuracy: 0.8212 - auc: 0.8985 - val_loss: 0.5109 - val_accuracy: 0.8095 - val_auc: 0.8780 - lr: 1.1080e-04
# Epoch 24/40
# 492/492 [==============================] - 3s 7ms/step - loss: 0.3966 - accuracy: 0.8213 - auc: 0.8990 - val_loss: 0.5159 - val_accuracy: 0.8069 - val_auc: 0.8765 - lr: 1.0026e-04
# Epoch 25/40
# 492/492 [==============================] - 3s 7ms/step - loss: 0.3921 - accuracy: 0.8213 - auc: 0.8980 - val_loss: 0.5147 - val_accuracy: 0.8114 - val_auc: 0.8802 - lr: 9.0718e-05
# Epoch 26/40
# 492/492 [==============================] - 3s 7ms/step - loss: 0.3946 - accuracy: 0.8233 - auc: 0.9006 - val_loss: 0.5228 - val_accuracy: 0.8077 - val_auc: 0.8762 - lr: 8.2085e-05
# ----------------Start model 2---------------------
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirecti  (None, 256)               132864
#  onal)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 133378 (521.01 KB)
# Trainable params: 133378 (521.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 492/492 [==============================] - 7s 10ms/step - loss: 0.5600 - accuracy: 0.7302 - auc: 0.7921 - val_loss: 0.4704 - val_accuracy: 0.7966 - val_auc: 0.8651 - lr: 0.0010
# Epoch 2/40
# 492/492 [==============================] - 5s 9ms/step - loss: 0.5129 - accuracy: 0.7650 - auc: 0.8305 - val_loss: 0.4522 - val_accuracy: 0.8101 - val_auc: 0.8757 - lr: 9.0484e-04
# Epoch 3/40
# 492/492 [==============================] - 5s 9ms/step - loss: 0.4952 - accuracy: 0.7717 - auc: 0.8399 - val_loss: 0.4918 - val_accuracy: 0.7825 - val_auc: 0.8466 - lr: 8.1873e-04
# Epoch 4/40
# 492/492 [==============================] - 5s 9ms/step - loss: 0.4810 - accuracy: 0.7815 - auc: 0.8509 - val_loss: 0.4940 - val_accuracy: 0.7761 - val_auc: 0.8440 - lr: 7.4082e-04
# Epoch 5/40
# 492/492 [==============================] - 4s 9ms/step - loss: 0.4701 - accuracy: 0.7845 - auc: 0.8560 - val_loss: 0.4901 - val_accuracy: 0.7761 - val_auc: 0.8459 - lr: 6.7032e-04
# Epoch 6/40
# 492/492 [==============================] - 4s 9ms/step - loss: 0.4584 - accuracy: 0.7897 - auc: 0.8634 - val_loss: 0.4563 - val_accuracy: 0.7977 - val_auc: 0.8692 - lr: 6.0653e-04
# Epoch 7/40
# 492/492 [==============================] - 4s 9ms/step - loss: 0.4441 - accuracy: 0.7974 - auc: 0.8716 - val_loss: 0.4590 - val_accuracy: 0.8015 - val_auc: 0.8686 - lr: 5.4881e-04
# ----------------Start model 3---------------------
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirecti  (None, 128)               41856
#  onal)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 42114 (164.51 KB)
# Trainable params: 42114 (164.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 492/492 [==============================] - 5s 7ms/step - loss: 0.5819 - accuracy: 0.7209 - auc: 0.7778 - val_loss: 0.5326 - val_accuracy: 0.7655 - val_auc: 0.8244 - lr: 0.0010
# Epoch 2/40
# 492/492 [==============================] - 3s 6ms/step - loss: 0.5271 - accuracy: 0.7581 - auc: 0.8172 - val_loss: 0.5046 - val_accuracy: 0.7765 - val_auc: 0.8407 - lr: 9.0484e-04
# Epoch 3/40
# 492/492 [==============================] - 3s 6ms/step - loss: 0.5083 - accuracy: 0.7678 - auc: 0.8323 - val_loss: 0.5237 - val_accuracy: 0.7678 - val_auc: 0.8268 - lr: 8.1873e-04
# Epoch 4/40
# 492/492 [==============================] - 3s 6ms/step - loss: 0.4992 - accuracy: 0.7724 - auc: 0.8394 - val_loss: 0.4587 - val_accuracy: 0.8017 - val_auc: 0.8709 - lr: 7.4082e-04
# Epoch 5/40
# 492/492 [==============================] - 3s 6ms/step - loss: 0.4844 - accuracy: 0.7782 - auc: 0.8477 - val_loss: 0.4750 - val_accuracy: 0.7922 - val_auc: 0.8612 - lr: 6.7032e-04
# Epoch 6/40
# 492/492 [==============================] - 3s 6ms/step - loss: 0.4774 - accuracy: 0.7823 - auc: 0.8546 - val_loss: 0.5070 - val_accuracy: 0.7760 - val_auc: 0.8415 - lr: 6.0653e-04
# Epoch 7/40
# 492/492 [==============================] - 3s 6ms/step - loss: 0.4685 - accuracy: 0.7851 - auc: 0.8582 - val_loss: 0.4744 - val_accuracy: 0.7975 - val_auc: 0.8667 - lr: 5.4881e-04
# Epoch 8/40
# 492/492 [==============================] - 3s 6ms/step - loss: 0.4595 - accuracy: 0.7900 - auc: 0.8640 - val_loss: 0.4765 - val_accuracy: 0.7975 - val_auc: 0.8661 - lr: 4.9659e-04
# Epoch 9/40
# 492/492 [==============================] - 3s 7ms/step - loss: 0.4553 - accuracy: 0.7950 - auc: 0.8679 - val_loss: 0.4827 - val_accuracy: 0.7927 - val_auc: 0.8639 - lr: 4.4933e-04

# %%
import matplotlib.pyplot as plt

lr_name = ['Step-base', 'Time-base', 'Exponential-base']
for i, _ in enumerate(m_hist):
  # Create a figure with two subplots side by side
  fig, (plt1, plt2, plt3) = plt.subplots(1, 3, figsize=(15, 5))

  # plt.plot(m.history['loss'])
  plt1.plot(m_hist[i].history['accuracy'])
  plt1.plot(m_hist[i].history['val_accuracy'])
  plt1.set_title('model accuracy')
  plt1.set_ylabel('accuracy')
  plt1.set_xlabel('epoch')
  plt1.legend(['accuracy', 'val_accuracy'], loc='upper left')

  # plt.plot(m.history['loss'])
  plt2.plot(m_hist[i].history['auc'])
  plt2.plot(m_hist[i].history['val_auc'])
  plt2.set_title('model auc')
  plt2.set_ylabel('auc')
  plt2.set_xlabel('epoch')
  plt2.legend(['auc', 'val_auc'], loc='upper left')

  # plt.plot(m.history['loss'])
  plt3.plot(m_hist[i].history['loss'])
  plt3.plot(m_hist[i].history['val_loss'])
  plt3.set_title('model loss')
  plt3.set_ylabel('loss')
  plt3.set_xlabel('epoch')
  plt3.legend(['loss', 'val_loss'], loc='upper left')

  plt.tight_layout()
  plt.show()

# %%
fig, (plt1, plt2, plt3) = plt.subplots(1, 3, figsize=(15, 5))
plts = [plt1, plt2, plt3]

chart_types = ['val_accuracy', 'val_auc', 'val_loss']

for i, chart_type in enumerate(chart_types):
  k = 0
  plts[i].plot(m_hist[k].history[chart_type])
  plts[i].plot(m_hist[k+1].history[chart_type])
  plts[i].plot(m_hist[k+2].history[chart_type])
  plts[i].plot(m_hist[k+3].history[chart_type])
  plts[i].legend([f"Bi LSTM {chart_type}", f"Bi GRU {chart_type}"], loc="lower right")

# %%
from keras.models import load_model
reload(me)

trained_models = {}
model_names = ['Bi-LSTM-128', 'Bi-GRU-128', 'Bi-LSTM-64', 'Bi-GRU-64']
for i, m in enumerate(model_names):
  print("Inference:")
  model = load_model(f"weights_best_struct_bi_{i}.hdf5")
  model.optimizer.lr.numpy()
  trained_models[m] = model

me.plot_combined_roc_curves(trained_models, x_train, y_train, x_test, y_test)
# me.print_results(model, x_train, y_train, x_test, y_test)
# Out:
# Inference:
# Inference:
# Inference:
# Inference:
# 983/983 [==============================] - 4s 4ms/step
# 289/289 [==============================] - 1s 4ms/step
# 983/983 [==============================] - 3s 3ms/step
# 289/289 [==============================] - 1s 3ms/step
# 983/983 [==============================] - 4s 3ms/step
# 289/289 [==============================] - 1s 3ms/step
# 983/983 [==============================] - 3s 3ms/step
# 289/289 [==============================] - 1s 3ms/step
#          Model  Balanced acc Train  Balanced acc Test  Precision Train  \
# 0  Bi-LSTM-128            0.754384           0.739340         0.297441
# 1   Bi-GRU-128            0.827425           0.749046         0.376291
# 2   Bi-LSTM-64            0.765536           0.751281         0.319208
# 3    Bi-GRU-64            0.775251           0.748401         0.316604
#
#    Precision Test  Recall Train  Recall Test  F1 Train   F1 Test
# 0        0.289193      0.711413     0.680402  0.419493  0.405875
# 1        0.313052      0.818451     0.677387  0.515552  0.428208
# 2        0.315765      0.714962     0.680402  0.441362  0.431348
# 3        0.299175      0.744234     0.692462  0.444229  0.417829
